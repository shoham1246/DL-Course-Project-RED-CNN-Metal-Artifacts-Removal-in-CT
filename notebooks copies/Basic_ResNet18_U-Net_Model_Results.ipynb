# %% [markdown]
# # Basic ResNet18 U-Net Model Results
#
# In this notebook we display some results that were gotten from the Basic ResNet18 U-Net Model we created on the test set (test patient L506).
# As one can see, the output images which are produced by the deep net, **have much worse quality even from the input quater dose images** (in terms of RMSE, SSIM, and PSNR).
#
# The display format:
#
# **Input**, low-dosed image   **||**   **Net** output image **||**  **GT**, normal-dosed image

# %% [markdown]
# ![alt text](image-3.png)

# %% [markdown]
# ![alt text](image-2.png)

# %% [markdown]
# ![alt text](image-1.png)

# %% [markdown]
# ![alt text](image.png)
