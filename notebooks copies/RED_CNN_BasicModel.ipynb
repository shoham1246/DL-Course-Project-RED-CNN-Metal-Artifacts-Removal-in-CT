# %% [markdown]
# # Implementation of RED CNN
# forked from SSinyu/RED-CNN, edited by Nili and Shoham
# (insert IN THE END picture, too annoying)
#
# Running Order:
# 1.   Cell 4 (prep.py)
# 2.   Cell 7 (main.py) - for train
# 3.   Cell 7 (main.py) - for test

# %% [markdown]
# **Cell 0:** upload data from drive and organize it properly

# %%
#from google.colab import drive
#drive.mount('/content/drive/3mmB30')

#!gdown --folder https://drive.google.com/drive/folders/1cvmktRMZHnKOnpT9U77i_aZ56xMsNQ59?usp=sharing

# Download the single zip file using its ID
# !gdown --id 1G6EE1aNvP-c4bi8cUGKkP2o2313-NvgY -O 3mmB30.zip

# Unzip the contents into your Colab environment and remove the zip
# !unzip -q 3mmB30.zip -d 3mmB30
# !rm 3mmB30.zip

# !mv /content/3mmB30/*3mm*B30*/L* /content/3mmB30/
# !rm -r /content/3mmB30/*3mm*B30*
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1G6EE1aNvP-c4bi8cUGKkP2o2313-NvgY
# From (redirected): https://drive.google.com/uc?id=1G6EE1aNvP-c4bi8cUGKkP2o2313-NvgY&confirm=t&uuid=0df3aeb4-21e7-480f-8ff1-c1af7526030d
# To: /content/3mmB30.zip
# 100% 1.47G/1.47G [00:17<00:00, 83.6MB/s]
# mv: cannot move '/content/3mmB30/‏‏3mmB30/L067' to '/content/3mmB30/L067': Directory not empty
# mv: cannot move '/content/3mmB30/‏‏3mmB30/L096' to '/content/3mmB30/L096': Directory not empty
# mv: cannot move '/content/3mmB30/‏‏3mmB30/L109' to '/content/3mmB30/L109': Directory not empty
# mv: cannot move '/content/3mmB30/‏‏3mmB30/L143' to '/content/3mmB30/L143': Directory not empty
# mv: cannot move '/content/3mmB30/‏‏3mmB30/L192' to '/content/3mmB30/L192': Directory not empty
# mv: cannot move '/content/3mmB30/‏‏3mmB30/L286' to '/content/3mmB30/L286': Directory not empty
# mv: cannot move '/content/3mmB30/‏‏3mmB30/L291' to '/content/3mmB30/L291': Directory not empty
# mv: cannot move '/content/3mmB30/‏‏3mmB30/L310' to '/content/3mmB30/L310': Directory not empty
# mv: cannot move '/content/3mmB30/‏‏3mmB30/L333' to '/content/3mmB30/L333': Directory not empty
# mv: cannot move '/content/3mmB30/‏‏3mmB30/L506' to '/content/3mmB30/L506': Directory not empty

# %% [markdown]
# **Cell** **1**: Improts  and Installing

# %%
# !pip install pydicom

import os
import time
import argparse
from glob import glob
from collections import OrderedDict
from math import exp

import numpy as np
import pydicom
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
from torch.backends import cudnn
# Out:
# Requirement already satisfied: pydicom in /usr/local/lib/python3.12/dist-packages (3.0.2)

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# **Cell 2:** Model class description, including all layers and feed forward method.
# *   **Encoder**: first 5 conv layers
# *   **Decoder**: last 5 deconv layers, including skip connections.
#
# Every Conv/Deconv layer, starting from the second, works on 96 feature channels in a 5x5 kernel, as decided emprically by the original creatores of RED CNN, since it captures enough details without making the model too heavy.
#
# **Based on:** networks.py

# %%
class RED_CNN(nn.Module):
    def __init__(self, out_ch=96):
        super(RED_CNN, self).__init__()
        # Encoder:
        self.conv1 = nn.Conv2d(1, out_ch, kernel_size=5, stride=1, padding=0)
        self.conv2 = nn.Conv2d(out_ch, out_ch, kernel_size=5, stride=1, padding=0)
        self.conv3 = nn.Conv2d(out_ch, out_ch, kernel_size=5, stride=1, padding=0)
        self.conv4 = nn.Conv2d(out_ch, out_ch, kernel_size=5, stride=1, padding=0)
        self.conv5 = nn.Conv2d(out_ch, out_ch, kernel_size=5, stride=1, padding=0)
        # Decoder:
        self.tconv1 = nn.ConvTranspose2d(out_ch, out_ch, kernel_size=5, stride=1, padding=0)
        self.tconv2 = nn.ConvTranspose2d(out_ch, out_ch, kernel_size=5, stride=1, padding=0)
        self.tconv3 = nn.ConvTranspose2d(out_ch, out_ch, kernel_size=5, stride=1, padding=0)
        self.tconv4 = nn.ConvTranspose2d(out_ch, out_ch, kernel_size=5, stride=1, padding=0)
        self.tconv5 = nn.ConvTranspose2d(out_ch, 1, kernel_size=5, stride=1, padding=0)

        self.relu = nn.ReLU()

    def forward(self, x):
        # Encoder
        residual_1 = x
        out = self.relu(self.conv1(x))
        out = self.relu(self.conv2(out))
        residual_2 = out
        out = self.relu(self.conv3(out))
        out = self.relu(self.conv4(out))
        residual_3 = out
        out = self.relu(self.conv5(out))
        # Decoder
        out = self.tconv1(out)
        out += residual_3
        out = self.tconv2(self.relu(out))
        out = self.tconv3(self.relu(out))
        out += residual_2
        out = self.tconv4(self.relu(out))
        out = self.tconv5(self.relu(out))
        out += residual_1
        out = self.relu(out)
        return out

# %% [markdown]
# **Cell 3:** Metrics for Evaluting the net (image) output. Contain primary function "compute_measure" that evaluting the output using different methods, such as:
#
# 1.   **PSNR**: Measure Peak Signal to Noise Ratio. Peak Signal is (data_range)^2. data_range = trunc_max - trunc_min. May be different between Mayo images and MAR images. Noise is the average power of the error signal. Higher PSNR expected from the net output.
# 2.   **SSIM**: Measure the Structural Similarity Index (composed of 3 comparison kriteria: luminance, contrast, structure). Higher SSIM expected from the net output.
# 3.   **RMSE**: Measure the Root Mean Square Error between GT and input/output images. Less error expected from the net output.
#
# **Based on:** measure.py

# %%
# ----
# Main Evaluating func:
# ----
def compute_measure(x, y, pred, data_range):
    original_psnr = compute_PSNR(x, y, data_range)
    original_ssim = compute_SSIM(x, y, data_range)
    original_rmse = compute_RMSE(x, y)
    pred_psnr = compute_PSNR(pred, y, data_range)
    pred_ssim = compute_SSIM(pred, y, data_range)
    pred_rmse = compute_RMSE(pred, y)
    return (original_psnr, original_ssim, original_rmse), (pred_psnr, pred_ssim, pred_rmse)
# ----
# 1. RMSE
# ----
def compute_MSE(img1, img2):
    return ((img1 - img2) ** 2).mean()

def compute_RMSE(img1, img2):
    if type(img1) == torch.Tensor:
        return torch.sqrt(compute_MSE(img1, img2)).item()
    else:
        return np.sqrt(compute_MSE(img1, img2))
# ----
# 2. PSNR
# ----
def compute_PSNR(img1, img2, data_range):
    if type(img1) == torch.Tensor:
        mse_ = compute_MSE(img1, img2)
        return 10 * torch.log10((data_range ** 2) / mse_).item()
    else:
        mse_ = compute_MSE(img1, img2)
        return 10 * np.log10((data_range ** 2) / mse_)
# ----
# 3. SSIM
# ----
def compute_SSIM(img1, img2, data_range, window_size=11, channel=1, size_average=True):
    if len(img1.size()) == 2:
        shape_ = img1.shape[-1]
        img1 = img1.view(1,1,shape_ ,shape_ )
        img2 = img2.view(1,1,shape_ ,shape_ )
    window = create_window(window_size, channel)
    window = window.type_as(img1)

    mu1 = F.conv2d(img1, window, padding=window_size//2)
    mu2 = F.conv2d(img2, window, padding=window_size//2)
    mu1_sq, mu2_sq = mu1.pow(2), mu2.pow(2)
    mu1_mu2 = mu1*mu2

    sigma1_sq = F.conv2d(img1*img1, window, padding=window_size//2) - mu1_sq
    sigma2_sq = F.conv2d(img2*img2, window, padding=window_size//2) - mu2_sq
    sigma12 = F.conv2d(img1*img2, window, padding=window_size//2) - mu1_mu2

    C1, C2 = (0.01*data_range)**2, (0.03*data_range)**2

    ssim_map = ((2*mu1_mu2+C1)*(2*sigma12+C2)) / ((mu1_sq+mu2_sq+C1)*(sigma1_sq+sigma2_sq+C2)) # final term - all 3 comps combined
    if size_average:
        return ssim_map.mean().item()
    else:
        return ssim_map.mean(1).mean(1).mean(1).item()

def gaussian(window_size, sigma):
    gauss = torch.Tensor([exp(-(x - window_size // 2) ** 2 / float(2 * sigma ** 2)) for x in range(window_size)])
    return gauss / gauss.sum()

def create_window(window_size, channel):
    _1D_window = gaussian(window_size, 1.5).unsqueeze(1)
    _2D_window = _1D_window.mm(_1D_window.t()).float().unsqueeze(0).unsqueeze(0)
    window = Variable(_2D_window.expand(channel, 1, window_size, window_size).contiguous())
    return window

# %% [markdown]
# **Cell 4:** Pre-Processing of the data. Process and organize the images:
# *   Converting to HU units and normalize data
# *   Create 3D slices vectors
# *   Find every slice exact thickness and save it to the metadata
# *   Convert all DCIM images to numpy format
#
# **Based on**: prep.py

# %%
def save_dataset(args):
    "convert given images to numpy arrays and save them"
    if not os.path.exists(args.save_path):
        os.makedirs(args.save_path)
        print('Create path : {}'.format(args.save_path))

    patients_list = sorted([d for d in os.listdir(args.data_path) if 'zip' not in d and d.startswith('L')])
    print(patients_list)
    for p_ind, patient in enumerate(patients_list):
        patient_input_path = os.path.join(args.data_path, patient,
                                          "quarter_{}mm".format(args.mm))
        print(patient_input_path)

        patient_target_path = os.path.join(args.data_path, patient,
                                           "full_{}mm".format(args.mm))

        for path_ in [patient_input_path, patient_target_path]:
            full_pixels = get_pixels_hu(load_scan(path_))
            for pi in range(len(full_pixels)):
                io = 'input' if 'quarter' in path_ else 'target'
                f = normalize_(full_pixels[pi], args.norm_range_min, args.norm_range_max)
                f_name = '{}_{}_{}.npy'.format(patient, pi, io)
                np.save(os.path.join(args.save_path, f_name), f)

        printProgressBar(p_ind, len(patients_list),
                         prefix="save image ..",
                         suffix='Complete', length=25)
        print(' ')

def load_scan(path):
    """referred from https://www.kaggle.com/gzuidhof/full-preprocessing-tutorial.
    Extract slice thickness from every file"""
    # 1. Read all DICOM files from the folder and store them in a list
    # os.listdir gets the filenames, pydicom.read_file opens and parses each file
    # but pydicom.read_file not exist anymore, instead we use pydicom.dcmread
    slices = [pydicom.dcmread(os.path.join(path, s)) for s in os.listdir(path)]

    # 2. Sort the slices into their correct anatomical 3D sequence
    # ImagePositionPatient[2] extracts the physical Z-axis coordinate of the scan
    slices.sort(key=lambda x: float(x.ImagePositionPatient[2]))

    # 3. Mathematically calculate the real physical distance between image slices
    try:
        # Primary method: calculate absolute difference between the Z-coordinates of slice 0 and slice 1
        slice_thickness = np.abs(slices[0].ImagePositionPatient[2] - slices[1].ImagePositionPatient[2])
    except:
        # Fallback method: if the machine didn't record ImagePositionPatient, try SliceLocation instead
        slice_thickness = np.abs(slices[0].SliceLocation - slices[1].SliceLocation)

    # 4. Overwrite the default thickness metadata on every slice
    # (Because the built-in DICOM SliceThickness tag is often missing or unreliable)
    for s in slices:
        s.SliceThickness = slice_thickness

    # 5. Return the sorted, corrected list of DICOM objects
    return slices

def get_pixels_hu(slices):
    # referred from https://www.kaggle.com/gzuidhof/full-preprocessing-tutorial

    # 1. Extract the raw 2D pixel arrays from each DICOM slice  and stack them together to create a single 3D NumPy volume.
    image = np.stack([s.pixel_array for s in slices])

    # 2. Convert the pixel values to 16-bit integers.
    # only in Mayo!
    image = image.astype(np.int16)

    # 3. Handle pixels that fall outside the physical scanning cylinder.
    # Scanners often fill empty space/padding with an artificial value like -2000.
    # This resets that padding to 0 (or air) so it doesn't skew the network's calculations.
    image[image == -2000] = 0

    # 4. Convert the raw machine pixels to standard Hounsfield Units (HU).
    # The formula is: HU = (Raw_Pixel_Value * Rescale_Slope) + Rescale_Intercept
    for slice_number in range(len(slices)):

        # Extract the specific slope and intercept metadata attached to this slice
        intercept = slices[slice_number].RescaleIntercept
        slope = slices[slice_number].RescaleSlope

        # Apply the slope multiplier (1 is just be multiplying by itself)
        if slope != 1:
            image[slice_number] = slope * image[slice_number].astype(np.float64)
            image[slice_number] = image[slice_number].astype(np.int16)

        # Add the intercept shift
        image[slice_number] += np.int16(intercept)

    # Return the final 3D volume, now accurately representing physical tissue density in HU
    return np.array(image, dtype=np.int16)


def normalize_(image, MIN_B=-1024.0, MAX_B=3072.0):
   image = (image - MIN_B) / (MAX_B - MIN_B)
   return image


def printProgressBar(iteration, total, prefix='', suffix='', decimals=1, length=100, fill=' '):
    # referred from https://gist.github.com/snakers4/91fa21b9dda9d055a02ecd23f24fbc3d
    percent = ("""{0:.""" + str(decimals) + """f}""").format(100 * (iteration / float(total)))
    filledLength = int(length * iteration // total)
    bar = fill * filledLength + '=' * (length - filledLength)
    print('\r%s |%s| %s%% %s' % (prefix, bar, percent, suffix), end='\r')
    if iteration == total:
        print()

# This block only runs if this script is executed directly
if __name__ == "__main__":
    import argparse # (Import usually at the top of the file)
    parser = argparse.ArgumentParser()

    # Define where the raw DICOM files are located
    parser.add_argument('--data_path', type=str, default='./content/3mmB30')

    # Define where the processed 3D NumPy arrays (.npy files) should be saved
    parser.add_argument('--save_path', type=str, default='./npy_img/')

    # Define which patient ID to hold out from training to use for testing/evaluation later
    parser.add_argument('--test_patient', type=str, default='L506')

    # Target slice thickness in millimeters (mm) to standardize the 3D volume resolution
    parser.add_argument('--mm', type=int, default=3)

    # Define the windowing/clipping range for the Hounsfield Units.
    # Neural networks prefer data within a tight, normalized range.
    # Any tissue density below -1024 HU (air) or above 3072 HU (dense bone/metal)
    # will be clipped to these boundaries before being normalized between 0 and 1.
    parser.add_argument('--norm_range_min', type=float, default=-1024.0)
    parser.add_argument('--norm_range_max', type=float, default=3072.0)

    # For terminal: Parse all the provided arguments and store them in the 'args' variable
    # args = parser.parse_args()

    ########
    # For colab:
    # Passing 'args=[]' forces argparse to parse an empty list
    # instead of reading Jupyter/Colab's hidden system arguments (which causes crashes).
    # This essentially loads all the 'default' values defined above into the 'args' variable.
    args = parser.parse_args(args=[])
    # Since we bypassed the command line, we manually overwrite any variables
    # to match our Google Colab environment setup.
    args.data_path = "/content/3mmB30"
    args.save_path = "/content/npy_img"
    ########

    # Trigger the main preprocessing pipeline using these settings
    save_dataset(args)
# Out:
# Create path : /content/npy_img
# ['L067', 'L096', 'L109', 'L143', 'L192', 'L286', 'L291', 'L310', 'L333', 'L506']
# /content/3mmB30/L067/quarter_3mm
#
# /content/3mmB30/L096/quarter_3mm
#
# /content/3mmB30/L109/quarter_3mm
#
# /content/3mmB30/L143/quarter_3mm
#
# /content/3mmB30/L192/quarter_3mm
#
# /content/3mmB30/L286/quarter_3mm
#
# /content/3mmB30/L291/quarter_3mm
#
# /content/3mmB30/L310/quarter_3mm
#
# /content/3mmB30/L333/quarter_3mm
#
# /content/3mmB30/L506/quarter_3mm

# %% [markdown]
# **Cell 5:** Definition of Dataset Class and DataLoader object
# *   **ct_dataset**: Class that holds all the patches of all the images of all the chosen patients (after desired transform).
# *   **data_loader**: Creating batches and shuffling the data.
#
#
#
#
# **Based on**: loader.py

# %%
class ct_dataset(Dataset):
    """The MAYO data set composed of 10 subjects. According to current main,
    9 of them for train. each contains around 200 CT images, and from each we take 10 patches.
    that's make the data set size around 18,000 image samples. """
    def __init__(self, mode, load_mode, saved_path, test_patient, patch_n=None, patch_size=None, transform=None):
        assert mode in ['train', 'test'], "mode is 'train' or 'test'"
        assert load_mode in [0,1], "load_mode is 0 (slow) or 1 (fast, if RAM can spare 10GB)"

        input_path = sorted(glob(os.path.join(saved_path, '*_input.npy')))
        target_path = sorted(glob(os.path.join(saved_path, '*_target.npy')))
        self.load_mode = load_mode
        self.patch_n = patch_n # how many patches to take from single image
        self.patch_size = patch_size # if none, patch is entire image
        self.transform = transform # pre-proccessing or augmentation function

        if mode == 'train':
            input_ = [f for f in input_path if test_patient not in f]
            target_ = [f for f in target_path if test_patient not in f]
            if load_mode == 0:
                self.input_ = input_
                self.target_ = target_
            else:
                self.input_ = [np.load(f) for f in input_]
                self.target_ = [np.load(f) for f in target_]
        else:
            input_ = [f for f in input_path if test_patient in f]
            target_ = [f for f in target_path if test_patient in f]
            if load_mode == 0:
                self.input_ = input_
                self.target_ = target_
            else:
                self.input_ = [np.load(f) for f in input_]
                self.target_ = [np.load(f) for f in target_]

    def __len__(self): # size of data (num of pairs (input, target))
        return len(self.target_)

    def __getitem__(self, idx): # returns all n patches of certain pair (input image, gt image)
        input_img, target_img = self.input_[idx], self.target_[idx]
        if self.load_mode == 0:
            input_img, target_img = np.load(input_img), np.load(target_img)

        if self.transform:
            input_img = self.transform(input_img)
            target_img = self.transform(target_img)

        if self.patch_size:
            input_patches, target_patches = get_patch(input_img, target_img, self.patch_n, self.patch_size)
            return (input_patches, target_patches)
        else:
            return (input_img, target_img)

def get_patch(full_input_img, full_target_img, patch_n, patch_size):
    assert full_input_img.shape == full_target_img.shape
    patch_input_imgs = []
    patch_target_imgs = []
    h, w = full_input_img.shape
    new_h, new_w = patch_size, patch_size
    for _ in range(patch_n):
        top = np.random.randint(0, h-new_h) # each patch must start in valid place (not too much close to the edge)
        left = np.random.randint(0, w-new_w)
        patch_input_img = full_input_img[top:top+new_h, left:left+new_w]
        patch_target_img = full_target_img[top:top+new_h, left:left+new_w]
        patch_input_imgs.append(patch_input_img)
        patch_target_imgs.append(patch_target_img)
    return np.array(patch_input_imgs), np.array(patch_target_imgs)

def get_loader(mode='train', load_mode=0, saved_path=None, test_patient='L506',
               patch_n=None, patch_size=None, transform=None, batch_size=32, num_workers=6):
    dataset_ = ct_dataset(mode, load_mode, saved_path, test_patient, patch_n, patch_size, transform)
    data_loader = DataLoader(dataset=dataset_, batch_size=batch_size, shuffle=True, num_workers=num_workers)
    return data_loader

def printProgressBar(iteration, total, prefix='', suffix='', decimals=1, length=100, fill=' '):
    percent = ("{0:." + str(decimals) + "f}").format(100 * (iteration / float(total)))
    filledLength = int(length * iteration // total)
    bar = fill * filledLength + '=' * (length - filledLength)
    print('\r%s |%s| %s%% %s' % (prefix, bar, percent, suffix), end='\r')
    if iteration == total:
        print()

# %% [markdown]
# **Cell 6:** Definition of Solver Class, manager of all processes:
#
# *   Training
# *   Testing
# *   Data processing
# *   Saving figs and models
#
# **Based on**: solver.py

# %%
class Solver(object):
    def __init__(self, args, data_loader):
        """
        The Solver class handles the training and testing loops for the RED-CNN model.
        It manages data loading, model weight saving/loading, learning rate decay,
        loss calculation, and visualization of the results.
        """
        # Operational modes and data pipeline
        self.mode = args.mode
        self.load_mode = args.load_mode
        self.data_loader = data_loader

        # Device configuration (GPU vs CPU)
        if args.device:
            self.device = torch.device(args.device)
        else:
            self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        # Normalization and truncation limits for Hounsfield Units (HU)
        self.norm_range_min = args.norm_range_min
        self.norm_range_max = args.norm_range_max
        self.trunc_min = args.trunc_min
        self.trunc_max = args.trunc_max

        # File paths and hardware config
        self.save_path = args.save_path
        self.multi_gpu = args.multi_gpu

        # Training hyperparameters
        self.num_epochs = args.num_epochs
        self.print_iters = args.print_iters
        self.decay_iters = args.decay_iters
        self.save_iters = args.save_iters
        self.test_iters = args.test_iters
        self.result_fig = args.result_fig

        self.patch_size = args.patch_size

        # Initialize
        self.REDCNN = RED_CNN()

        # If multiple GPUs are available, wrap the model in DataParallel to split the workload
        if (self.multi_gpu) and (torch.cuda.device_count() > 1):
            print('Use {} GPUs'.format(torch.cuda.device_count()))
            self.REDCNN = nn.DataParallel(self.REDCNN)
        self.REDCNN.to(self.device)

        self.lr = args.lr
        self.criterion = nn.MSELoss()
        self.optimizer = optim.Adam(self.REDCNN.parameters(), self.lr)

    def save_model(self, iter_):
        """Saves the model's weights (state_dict) at a specific iteration."""
        f = os.path.join(self.save_path, 'REDCNN_{}iter.ckpt'.format(iter_))
        torch.save(self.REDCNN.state_dict(), f)

    def load_model(self, iter_):
        """Loads saved model weights. Handles multi-GPU formatting issues."""
        f = os.path.join(self.save_path, 'REDCNN_{}iter.ckpt'.format(iter_))
        if self.multi_gpu:
            # When a model is saved using nn.DataParallel, PyTorch adds 'module.'
            # to the beginning of every layer name. This loop removes that prefix
            # so the weights can be loaded correctly.
            state_d = OrderedDict()
            for k, v in torch.load(f):
                n = k[7:] # Skips the first 7 characters ('module.')
                state_d[n] = v
            self.REDCNN.load_state_dict(state_d)
        else:
            # Standard single-GPU loading
            self.REDCNN.load_state_dict(torch.load(f))

    def lr_decay(self):
        """Cuts the learning rate in half. Used to fine-tune the model as it converges."""
        lr = self.lr * 0.5
        for param_group in self.optimizer.param_groups:
            param_group['lr'] = lr

    def denormalize_(self, image):
        """Converts image tensors back from [0, 1] range to their original scale (HU)."""
        image = image * (self.norm_range_max - self.norm_range_min) + self.norm_range_min
        return image

    def trunc(self, mat):
        """Clips pixel values to ensure they stay within the predefined physical bounds."""
        # truncation used only in test mode so in one hand, the learning wont be affected
        # and in the other hand, in testing it will clip unexpected values.
        mat[mat <= self.trunc_min] = self.trunc_min
        mat[mat >= self.trunc_max] = self.trunc_max
        return mat

    def save_fig(self, x, y, pred, fig_name, original_result, pred_result):
        """Generates and saves a side-by-side comparison image of the input, target, and output."""
        # Convert PyTorch tensors to NumPy arrays for Matplotlib
        x, y, pred = x.numpy(), y.numpy(), pred.numpy()
        f, ax = plt.subplots(1, 3, figsize=(30, 10))
        # Plot Quarter-dose (Input)
        ax[0].imshow(x, cmap=plt.cm.gray, vmin=self.trunc_min, vmax=self.trunc_max)
        ax[0].set_title('Quarter-dose', fontsize=30)
        ax[0].set_xlabel("PSNR: {:.4f}\nSSIM: {:.4f}\nRMSE: {:.4f}".format(original_result[0], original_result[1], original_result[2]), fontsize=20)
        # Plot Prediction (Model Output)
        ax[1].imshow(pred, cmap=plt.cm.gray, vmin=self.trunc_min, vmax=self.trunc_max)
        ax[1].set_title('Result', fontsize=30)
        ax[1].set_xlabel("PSNR: {:.4f}\nSSIM: {:.4f}\nRMSE: {:.4f}".format(pred_result[0], pred_result[1], pred_result[2]), fontsize=20)
        # Plot Full-dose (Ground Truth Target)
        ax[2].imshow(y, cmap=plt.cm.gray, vmin=self.trunc_min, vmax=self.trunc_max)
        ax[2].set_title('Full-dose', fontsize=30)

        # In a notebook, we can both save it and display it (Save to disk and display in the notebook output)
        f.savefig(os.path.join(self.save_path, 'fig', 'result_{}.png'.format(fig_name)))
        plt.show()
        plt.close()

    def train(self):
        """The main training loop."""
        train_losses = []
        total_iters = 0
        start_time = time.time()
        for epoch in range(1, self.num_epochs):
            self.REDCNN.train(True)
            # x = low dose input, y = normal dose ground truth
            for iter_, (x, y) in enumerate(self.data_loader):
                total_iters += 1

                # Add a channel dimension (unsqueeze) and move data to the GPU/CPU
                x = x.unsqueeze(0).float().to(self.device)
                y = y.unsqueeze(0).float().to(self.device)

                # If processing in patches rather than full images, reshape the tensors
                if self.patch_size:
                    #for Conv2d, reshapes x into a 4D tensor with a single channel and a patch_size × patch_size spatial dimension, while automatically computing batch size.
                    x = x.view(-1, 1, self.patch_size, self.patch_size)
                    y = y.view(-1, 1, self.patch_size, self.patch_size)

                pred = self.REDCNN(x)
                loss = self.criterion(pred, y)
                self.REDCNN.zero_grad()
                self.optimizer.zero_grad()

                loss.backward()
                self.optimizer.step()
                train_losses.append(loss.item())

                if total_iters % self.print_iters == 0:
                    print("STEP [{}], EPOCH [{}/{}], ITER [{}/{}] \nLOSS: {:.8f}, TIME: {:.1f}s".format(
                        total_iters, epoch, self.num_epochs, iter_+1, len(self.data_loader), loss.item(), time.time() - start_time))

                # Decay learning rate at specific intervals
                if total_iters % self.decay_iters == 0:
                    self.lr_decay()

                # Save model checkpoints at specific intervals
                if total_iters % self.save_iters == 0:
                    self.save_model(total_iters)
                    np.save(os.path.join(self.save_path, 'loss_{}_iter.npy'.format(total_iters)), np.array(train_losses))

    def test(self):
        # Refresh the model to ensure a clean slate, then load the desired saved weights
        del self.REDCNN
        self.REDCNN = RED_CNN().to(self.device)
        self.load_model(self.test_iters)

        ori_psnr_avg, ori_ssim_avg, ori_rmse_avg = 0, 0, 0
        pred_psnr_avg, pred_ssim_avg, pred_rmse_avg = 0, 0, 0

        with torch.no_grad():
            for i, (x, y) in enumerate(self.data_loader):
                shape_ = x.shape[-1]
                x = x.unsqueeze(0).float().to(self.device)
                y = y.unsqueeze(0).float().to(self.device)

                pred = self.REDCNN(x)

                # Move tensors to CPU, remove from graph (.detach()), reshape to 2D, denormalize, and clip values
                x = self.trunc(self.denormalize_(x.view(shape_, shape_).cpu().detach()))
                y = self.trunc(self.denormalize_(y.view(shape_, shape_).cpu().detach()))
                pred = self.trunc(self.denormalize_(pred.view(shape_, shape_).cpu().detach()))

                data_range = self.trunc_max - self.trunc_min

                # Accumulate the metrics to calculate an average later
                original_result, pred_result = compute_measure(x, y, pred, data_range)
                ori_psnr_avg += original_result[0]
                ori_ssim_avg += original_result[1]
                ori_rmse_avg += original_result[2]
                pred_psnr_avg += pred_result[0]
                pred_ssim_avg += pred_result[1]
                pred_rmse_avg += pred_result[2]

                if self.result_fig:
                    self.save_fig(x, y, pred, i, original_result, pred_result)

                printProgressBar(i, len(self.data_loader), prefix="Compute measurements ..", suffix='Complete', length=25)
            print('\n')
            print('Original === \nPSNR avg: {:.4f} \nSSIM avg: {:.4f} \nRMSE avg: {:.4f}'.format(
                ori_psnr_avg/len(self.data_loader), ori_ssim_avg/len(self.data_loader), ori_rmse_avg/len(self.data_loader)))
            print('\n')
            print('Predictions === \nPSNR avg: {:.4f} \nSSIM avg: {:.4f} \nRMSE avg: {:.4f}'.format(
                pred_psnr_avg/len(self.data_loader), pred_ssim_avg/len(self.data_loader), pred_rmse_avg/len(self.data_loader)))

# %% [markdown]
# **Cell 7:** Running Main to train or test the model.
#
# *  Initilize parameters: a path for saving models and figures, data loader for test or train, patch_size, batch_size etc.
# *   Initialize the Solver for training or testing
# *   Pass parameters as arguments for the solver
# *  Execute the Solver according to it's mode, train or test.
#
# **Based on**: main.py

# %%
def main(args):
    # Optimizes CuDNN for faster training if your input sizes don't change
    cudnn.benchmark = True

    # Create directories for saving models and figures if they don't exist
    if not os.path.exists(args.save_path):
        os.makedirs(args.save_path)
        print('Create path : {}'.format(args.save_path))

    if args.result_fig:
        fig_path = os.path.join(args.save_path, 'fig')
        if not os.path.exists(fig_path):
            os.makedirs(fig_path)
            print('Create path : {}'.format(fig_path))

    # Initialize the data loader
    data_loader = get_loader(mode=args.mode,
                             load_mode=args.load_mode,
                             saved_path=args.saved_path,
                             test_patient=args.test_patient,
                             patch_n=(args.patch_n if args.mode=='train' else None),
                             patch_size=(args.patch_size if args.mode=='train' else None),
                             transform=args.transform,
                             batch_size=(args.batch_size if args.mode=='train' else 1),
                             num_workers=args.num_workers)

    # Initialize the Solver and start training or testing
    solver = Solver(args, data_loader)
    if args.mode == 'train':
        solver.train()
    elif args.mode == 'test':
        solver.test()


# Colab specific setup
parser = argparse.ArgumentParser()

# ---------------------------------------------------------
# ARGUMENTS (You can change default values here)
# ---------------------------------------------------------
parser.add_argument('--mode', type=str, default='test') # Change to 'test' when you want to evaluate
parser.add_argument('--load_mode', type=int, default=0)

# Paths (Adjust these to match Colab /content/ folders)
parser.add_argument('--data_path', type=str, default='/content/3mm B30/')
parser.add_argument('--saved_path', type=str, default='/content/npy_img/')
parser.add_argument('--save_path', type=str, default='/content/save/')
parser.add_argument('--test_patient', type=str, default='L506')
parser.add_argument('--result_fig', type=bool, default=True)

# Image Normalization and Truncation bounds (HU limits)
parser.add_argument('--norm_range_min', type=float, default=-1024.0)
parser.add_argument('--norm_range_max', type=float, default=3072.0)
parser.add_argument('--trunc_min', type=float, default=-160.0)
parser.add_argument('--trunc_max', type=float, default=240.0)

# Data Augmentation and Patch Config
parser.add_argument('--transform', type=bool, default=False)
parser.add_argument('--patch_n', type=int, default=10)
parser.add_argument('--patch_size', type=int, default=64)
parser.add_argument('--batch_size', type=int, default=16)

# Training Hyperparameters
parser.add_argument('--num_epochs', type=int, default=100)
parser.add_argument('--print_iters', type=int, default=20)
parser.add_argument('--decay_iters', type=int, default=3000)
parser.add_argument('--save_iters', type=int, default=1000)
parser.add_argument('--test_iters', type=int, default=1000)
parser.add_argument('--lr', type=float, default=1e-5)

# Hardware Config
parser.add_argument('--device', type=str)
parser.add_argument('--multi_gpu', type=bool, default=False)
# not more than 2 in colab
parser.add_argument('--num_workers', type=int, default=2)

# ---------------------------------------------------------
# EXECUTION
# ---------------------------------------------------------
args = parser.parse_args(args=[])

# exmp for overwrite an argument without hunting through the list above:
# args.mode = 'test'

main(args)

# %%
# Compress the folder
#!zip -r npy_img.zip /content/npy_img

# Download the zipped file
#from google.colab import files
#files.download('npy_img.zip')

# Compress the folder
#!zip -r save.zip /content/save

# Download the zipped file
#from google.colab import files
#files.download('save.zip')
# Out:
#   adding: content/npy_img/ (stored 0%)
#   adding: content/npy_img/L310_175_target.npy (deflated 82%)
#   adding: content/npy_img/L506_106_target.npy (deflated 83%)
#   adding: content/npy_img/L310_195_input.npy (deflated 80%)
#   adding: content/npy_img/L067_157_target.npy (deflated 81%)
#   adding: content/npy_img/L096_65_input.npy (deflated 80%)
#   adding: content/npy_img/L096_259_input.npy (deflated 79%)
#   adding: content/npy_img/L291_83_target.npy (deflated 82%)
#   adding: content/npy_img/L506_193_input.npy (deflated 80%)
#   adding: content/npy_img/L286_135_target.npy (deflated 82%)
#   adding: content/npy_img/L192_36_target.npy (deflated 83%)
#   adding: content/npy_img/L143_7_input.npy (deflated 80%)
#   adding: content/npy_img/L333_157_target.npy (deflated 82%)
#   adding: content/npy_img/L291_158_target.npy (deflated 81%)
#   adding: content/npy_img/L109_84_input.npy (deflated 80%)
#   adding: content/npy_img/L096_219_target.npy (deflated 81%)
#   adding: content/npy_img/L096_106_input.npy (deflated 80%)
#   adding: content/npy_img/L143_113_input.npy (deflated 80%)
#   adding: content/npy_img/L333_14_target.npy (deflated 84%)
#   adding: content/npy_img/L286_141_target.npy (deflated 82%)
#   adding: content/npy_img/L143_135_input.npy (deflated 81%)
#   adding: content/npy_img/L143_28_input.npy (deflated 80%)
#   adding: content/npy_img/L506_159_target.npy (deflated 81%)
#   adding: content/npy_img/L291_53_input.npy (deflated 81%)
#   adding: content/npy_img/L291_43_target.npy (deflated 83%)
#   adding: content/npy_img/L506_68_target.npy (deflated 83%)
#   adding: content/npy_img/L067_71_target.npy (deflated 82%)
#   adding: content/npy_img/L291_197_target.npy (deflated 81%)
#   adding: content/npy_img/L096_286_target.npy (deflated 81%)
#   adding: content/npy_img/L333_218_input.npy (deflated 81%)
#   adding: content/npy_img/L096_196_target.npy (deflated 82%)
#   adding: content/npy_img/L143_77_input.npy (deflated 80%)
#   adding: content/npy_img/L096_116_input.npy (deflated 81%)
#   adding: content/npy_img/L143_15_target.npy (deflated 82%)
#   adding: content/npy_img/L333_25_target.npy (deflated 84%)
#   adding: content/npy_img/L096_314_target.npy (deflated 81%)
#   adding: content/npy_img/L096_213_input.npy (deflated 80%)
#   adding: content/npy_img/L192_170_input.npy (deflated 81%)
#   adding: content/npy_img/L286_169_target.npy (deflated 82%)
#   adding: content/npy_img/L067_184_target.npy (deflated 81%)
#   adding: content/npy_img/L096_250_input.npy (deflated 79%)
#   adding: content/npy_img/L291_61_input.npy (deflated 82%)
#   adding: content/npy_img/L506_198_input.npy (deflated 80%)
#   adding: content/npy_img/L067_89_target.npy (deflated 81%)
#   adding: content/npy_img/L096_20_input.npy (deflated 82%)
#   adding: content/npy_img/L291_332_input.npy (deflated 82%)
#   adding: content/npy_img/L192_35_target.npy (deflated 83%)
#   adding: content/npy_img/L286_181_input.npy (deflated 81%)
#   adding: content/npy_img/L310_100_target.npy (deflated 82%)
#   adding: content/npy_img/L096_171_input.npy (deflated 81%)
#   adding: content/npy_img/L096_180_input.npy (deflated 80%)
#   adding: content/npy_img/L333_41_input.npy (deflated 82%)
#   adding: content/npy_img/L286_142_input.npy (deflated 81%)
#   adding: content/npy_img/L506_17_input.npy (deflated 82%)
#   adding: content/npy_img/L096_57_target.npy (deflated 82%)
#   adding: content/npy_img/L286_54_target.npy (deflated 83%)
#   adding: content/npy_img/L291_217_target.npy (deflated 81%)
#   adding: content/npy_img/L286_202_input.npy (deflated 81%)
#   adding: content/npy_img/L286_91_target.npy (deflated 82%)
#   adding: content/npy_img/L143_167_input.npy (deflated 80%)
#   adding: content/npy_img/L067_162_input.npy (deflated 80%)
#   adding: content/npy_img/L096_224_target.npy (deflated 81%)
#   adding: content/npy_img/L096_244_target.npy (deflated 81%)
#   adding: content/npy_img/L143_98_target.npy (deflated 81%)
#   adding: content/npy_img/L291_82_target.npy (deflated 82%)
#   adding: content/npy_img/L109_44_input.npy (deflated 81%)
#   adding: content/npy_img/L506_71_target.npy (deflated 83%)
#   adding: content/npy_img/L109_34_input.npy (deflated 81%)
#   adding: content/npy_img/L067_145_target.npy (deflated 81%)
#   adding: content/npy_img/L192_233_input.npy (deflated 80%)
#   adding: content/npy_img/L143_114_input.npy (deflated 80%)
#   adding: content/npy_img/L291_51_input.npy (deflated 81%)
#   adding: content/npy_img/L333_49_target.npy (deflated 83%)
#   adding: content/npy_img/L333_164_target.npy (deflated 82%)
#   adding: content/npy_img/L291_189_target.npy (deflated 81%)
#   adding: content/npy_img/L291_12_input.npy (deflated 81%)
#   adding: content/npy_img/L192_189_input.npy (deflated 80%)
#   adding: content/npy_img/L291_12_target.npy (deflated 83%)
#   adding: content/npy_img/L291_272_target.npy (deflated 81%)
#   adding: content/npy_img/L192_136_target.npy (deflated 83%)
#   adding: content/npy_img/L192_122_target.npy (deflated 83%)
#   adding: content/npy_img/L096_282_input.npy (deflated 80%)
#   adding: content/npy_img/L333_210_target.npy (deflated 82%)
#   adding: content/npy_img/L286_191_target.npy (deflated 82%)
#   adding: content/npy_img/L506_126_target.npy (deflated 83%)
#   adding: content/npy_img/L192_174_input.npy (deflated 81%)
#   adding: content/npy_img/L096_322_input.npy (deflated 81%)
#   adding: content/npy_img/L310_50_input.npy (deflated 81%)
#   adding: content/npy_img/L291_264_target.npy (deflated 81%)
#   adding: content/npy_img/L143_106_target.npy (deflated 81%)
#   adding: content/npy_img/L096_288_target.npy (deflated 82%)
#   adding: content/npy_img/L291_286_input.npy (deflated 80%)
#   adding: content/npy_img/L310_103_input.npy (deflated 81%)
#   adding: content/npy_img/L291_134_target.npy (deflated 81%)
#   adding: content/npy_img/L192_192_input.npy (deflated 80%)
#   adding: content/npy_img/L333_239_input.npy (deflated 80%)
#   adding: content/npy_img/L096_83_target.npy (deflated 81%)
#   adding: content/npy_img/L291_244_target.npy (deflated 81%)
#   adding: content/npy_img/L143_69_input.npy (deflated 80%)
#   adding: content/npy_img/L333_106_target.npy (deflated 82%)
#   adding: content/npy_img/L067_140_input.npy (deflated 80%)
#   adding: content/npy_img/L192_224_target.npy (deflated 81%)
#   adding: content/npy_img/L286_179_input.npy (deflated 81%)
#   adding: content/npy_img/L291_201_target.npy (deflated 81%)
#   adding: content/npy_img/L291_294_input.npy (deflated 80%)
#   adding: content/npy_img/L286_197_target.npy (deflated 82%)
#   adding: content/npy_img/L310_133_input.npy (deflated 80%)
#   adding: content/npy_img/L506_23_input.npy (deflated 82%)
#   adding: content/npy_img/L286_94_input.npy (deflated 81%)
#   adding: content/npy_img/L291_75_input.npy (deflated 81%)
#   adding: content/npy_img/L310_72_target.npy (deflated 82%)
#   adding: content/npy_img/L192_186_input.npy (deflated 80%)
#   adding: content/npy_img/L067_59_target.npy (deflated 82%)
#   adding: content/npy_img/L109_96_target.npy (deflated 81%)
#   adding: content/npy_img/L143_44_input.npy (deflated 80%)
#   adding: content/npy_img/L333_190_target.npy (deflated 82%)
#   adding: content/npy_img/L310_130_target.npy (deflated 82%)
#   adding: content/npy_img/L291_7_input.npy (deflated 82%)
#   adding: content/npy_img/L192_15_target.npy (deflated 84%)
#   adding: content/npy_img/L506_144_input.npy (deflated 81%)
#   adding: content/npy_img/L096_127_input.npy (deflated 81%)
#   adding: content/npy_img/L096_141_target.npy (deflated 82%)
#   adding: content/npy_img/L096_118_input.npy (deflated 81%)
#   adding: content/npy_img/L192_126_input.npy (deflated 82%)
#   adding: content/npy_img/L333_74_target.npy (deflated 83%)
#   adding: content/npy_img/L291_124_target.npy (deflated 81%)
#   adding: content/npy_img/L067_128_input.npy (deflated 80%)
#   adding: content/npy_img/L310_18_input.npy (deflated 82%)
#   adding: content/npy_img/L291_209_target.npy (deflated 81%)
#   adding: content/npy_img/L286_132_input.npy (deflated 81%)
#   adding: content/npy_img/L286_7_target.npy (deflated 84%)
#   adding: content/npy_img/L291_198_target.npy (deflated 81%)
#   adding: content/npy_img/L310_22_target.npy (deflated 84%)
#   adding: content/npy_img/L192_97_target.npy (deflated 83%)
#   adding: content/npy_img/L310_185_input.npy (deflated 80%)
#   adding: content/npy_img/L286_99_target.npy (deflated 82%)
#   adding: content/npy_img/L506_157_input.npy (deflated 80%)
#   adding: content/npy_img/L096_157_input.npy (deflated 81%)
#   adding: content/npy_img/L333_116_input.npy (deflated 81%)
#   adding: content/npy_img/L310_43_input.npy (deflated 82%)
#   adding: content/npy_img/L192_58_input.npy (deflated 82%)
#   adding: content/npy_img/L192_9_target.npy (deflated 84%)
#   adding: content/npy_img/L286_140_input.npy (deflated 81%)
#   adding: content/npy_img/L096_182_target.npy (deflated 82%)
#   adding: content/npy_img/L109_40_input.npy (deflated 81%)
#   adding: content/npy_img/L109_24_target.npy (deflated 82%)
#   adding: content/npy_img/L291_117_input.npy (deflated 80%)
#   adding: content/npy_img/L291_103_target.npy (deflated 81%)
#   adding: content/npy_img/L310_110_input.npy (deflated 81%)
#   adding: content/npy_img/L096_311_target.npy (deflated 82%)
#   adding: content/npy_img/L067_9_target.npy (deflated 82%)
#   adding: content/npy_img/L333_228_input.npy (deflated 81%)
#   adding: content/npy_img/L067_12_target.npy (deflated 82%)
#   adding: content/npy_img/L506_101_target.npy (deflated 83%)
#   adding: content/npy_img/L291_178_input.npy (deflated 80%)
#   adding: content/npy_img/L096_293_input.npy (deflated 80%)
#   adding: content/npy_img/L096_139_target.npy (deflated 82%)
#   adding: content/npy_img/L506_196_input.npy (deflated 80%)
#   adding: content/npy_img/L291_28_target.npy (deflated 83%)
#   adding: content/npy_img/L506_95_input.npy (deflated 81%)
#   adding: content/npy_img/L192_137_target.npy (deflated 83%)
#   adding: content/npy_img/L506_82_input.npy (deflated 81%)
#   adding: content/npy_img/L286_108_target.npy (deflated 82%)
#   adding: content/npy_img/L286_28_target.npy (deflated 83%)
#   adding: content/npy_img/L286_119_input.npy (deflated 81%)
#   adding: content/npy_img/L291_330_input.npy (deflated 82%)
#   adding: content/npy_img/L291_155_input.npy (deflated 80%)
#   adding: content/npy_img/L291_146_input.npy (deflated 80%)
#   adding: content/npy_img/L143_101_input.npy (deflated 80%)
#   adding: content/npy_img/L291_5_input.npy (deflated 81%)
#   adding: content/npy_img/L291_262_input.npy (deflated 80%)
#   adding: content/npy_img/L333_43_input.npy (deflated 82%)
#   adding: content/npy_img/L291_136_input.npy (deflated 80%)
#   adding: content/npy_img/L067_158_input.npy (deflated 80%)
#   adding: content/npy_img/L506_8_target.npy (deflated 84%)
#   adding: content/npy_img/L286_32_target.npy (deflated 83%)
#   adding: content/npy_img/L291_151_input.npy (deflated 80%)
#   adding: content/npy_img/L333_30_input.npy (deflated 82%)
#   adding: content/npy_img/L310_111_input.npy (deflated 81%)
#   adding: content/npy_img/L192_150_input.npy (deflated 81%)
#   adding: content/npy_img/L192_195_target.npy (deflated 82%)
#   adding: content/npy_img/L333_115_target.npy (deflated 82%)
#   adding: content/npy_img/L096_64_target.npy (deflated 82%)
#   adding: content/npy_img/L143_216_input.npy (deflated 81%)
#   adding: content/npy_img/L143_215_target.npy (deflated 83%)
#   adding: content/npy_img/L291_115_target.npy (deflated 81%)
#   adding: content/npy_img/L109_49_input.npy (deflated 81%)
#   adding: content/npy_img/L506_151_target.npy (deflated 82%)
#   adding: content/npy_img/L333_97_input.npy (deflated 81%)
#   adding: content/npy_img/L291_186_target.npy (deflated 81%)
#   adding: content/npy_img/L506_185_target.npy (deflated 81%)
#   adding: content/npy_img/L192_119_target.npy (deflated 83%)
#   adding: content/npy_img/L067_223_input.npy (deflated 79%)
#   adding: content/npy_img/L109_68_input.npy (deflated 80%)
#   adding: content/npy_img/L291_308_input.npy (deflated 81%)
#   adding: content/npy_img/L286_43_target.npy (deflated 83%)
#   adding: content/npy_img/L310_33_input.npy (deflated 82%)
#   adding: content/npy_img/L506_129_target.npy (deflated 83%)
#   adding: content/npy_img/L291_38_target.npy (deflated 83%)
#   adding: content/npy_img/L067_49_target.npy (deflated 82%)
#   adding: content/npy_img/L192_112_input.npy (deflated 82%)
#   adding: content/npy_img/L291_166_target.npy (deflated 81%)
#   adding: content/npy_img/L506_128_target.npy (deflated 83%)
#   adding: content/npy_img/L067_206_target.npy (deflated 81%)
#   adding: content/npy_img/L333_160_target.npy (deflated 82%)
#   adding: content/npy_img/L291_281_input.npy (deflated 80%)
#   adding: content/npy_img/L192_116_target.npy (deflated 83%)
#   adding: content/npy_img/L192_83_target.npy (deflated 83%)
#   adding: content/npy_img/L286_35_input.npy (deflated 81%)
#   adding: content/npy_img/L506_209_target.npy (deflated 81%)
#   adding: content/npy_img/L067_171_target.npy (deflated 81%)
#   adding: content/npy_img/L192_206_target.npy (deflated 82%)
#   adding: content/npy_img/L067_196_target.npy (deflated 81%)
#   adding: content/npy_img/L310_49_target.npy (deflated 83%)
#   adding: content/npy_img/L291_54_target.npy (deflated 83%)
#   adding: content/npy_img/L506_64_input.npy (deflated 81%)
#   adding: content/npy_img/L143_225_input.npy (deflated 82%)
#   adding: content/npy_img/L310_130_input.npy (deflated 80%)
#   adding: content/npy_img/L291_208_input.npy (deflated 79%)
#   adding: content/npy_img/L143_64_target.npy (deflated 82%)
#   adding: content/npy_img/L096_187_target.npy (deflated 82%)
#   adding: content/npy_img/L143_100_input.npy (deflated 80%)
#   adding: content/npy_img/L067_118_target.npy (deflated 81%)
#   adding: content/npy_img/L310_99_target.npy (deflated 82%)
#   adding: content/npy_img/L109_5_target.npy (deflated 82%)
#   adding: content/npy_img/L192_166_target.npy (deflated 82%)
#   adding: content/npy_img/L310_92_input.npy (deflated 81%)
#   adding: content/npy_img/L096_174_input.npy (deflated 81%)
#   adding: content/npy_img/L286_152_target.npy (deflated 82%)
#   adding: content/npy_img/L143_189_target.npy (deflated 81%)
#   adding: content/npy_img/L067_94_target.npy (deflated 81%)
#   adding: content/npy_img/L291_177_input.npy (deflated 79%)
#   adding: content/npy_img/L286_115_target.npy (deflated 82%)
#   adding: content/npy_img/L096_38_input.npy (deflated 81%)
#   adding: content/npy_img/L333_23_input.npy (deflated 82%)
#   adding: content/npy_img/L109_28_input.npy (deflated 81%)
#   adding: content/npy_img/L067_174_input.npy (deflated 79%)
#   adding: content/npy_img/L333_108_input.npy (deflated 81%)
#   adding: content/npy_img/L143_46_input.npy (deflated 80%)
#   adding: content/npy_img/L096_229_input.npy (deflated 80%)
#   adding: content/npy_img/L096_19_target.npy (deflated 83%)
#   adding: content/npy_img/L291_229_input.npy (deflated 80%)
#   adding: content/npy_img/L286_187_target.npy (deflated 82%)
#   adding: content/npy_img/L291_194_target.npy (deflated 81%)
#   adding: content/npy_img/L506_118_input.npy (deflated 81%)
#   adding: content/npy_img/L096_187_input.npy (deflated 80%)
#   adding: content/npy_img/L143_84_target.npy (deflated 81%)
#   adding: content/npy_img/L291_153_target.npy (deflated 81%)
#   adding: content/npy_img/L291_108_input.npy (deflated 80%)
#   adding: content/npy_img/L192_100_target.npy (deflated 83%)
#   adding: content/npy_img/L096_67_target.npy (deflated 82%)
#   adding: content/npy_img/L143_202_input.npy (deflated 81%)
#   adding: content/npy_img/L143_36_target.npy (deflated 82%)
#   adding: content/npy_img/L096_162_target.npy (deflated 82%)
#   adding: content/npy_img/L192_130_target.npy (deflated 83%)
#   adding: content/npy_img/L506_191_target.npy (deflated 81%)
#   adding: content/npy_img/L333_94_target.npy (deflated 83%)
#   adding: content/npy_img/L333_136_input.npy (deflated 81%)
#   adding: content/npy_img/L067_56_input.npy (deflated 81%)
#   adding: content/npy_img/L096_176_input.npy (deflated 80%)
#   adding: content/npy_img/L067_190_target.npy (deflated 81%)
#   adding: content/npy_img/L143_14_target.npy (deflated 82%)
#   adding: content/npy_img/L291_35_target.npy (deflated 83%)
#   adding: content/npy_img/L143_52_target.npy (deflated 82%)
#   adding: content/npy_img/L067_154_input.npy (deflated 80%)
#   adding: content/npy_img/L286_47_target.npy (deflated 83%)
#   adding: content/npy_img/L067_126_input.npy (deflated 80%)
#   adding: content/npy_img/L067_65_input.npy (deflated 80%)
#   adding: content/npy_img/L109_31_target.npy (deflated 82%)
#   adding: content/npy_img/L143_172_target.npy (deflated 81%)
#   adding: content/npy_img/L291_279_input.npy (deflated 80%)
#   adding: content/npy_img/L109_102_input.npy (deflated 80%)
#   adding: content/npy_img/L506_6_input.npy (deflated 82%)
#   adding: content/npy_img/L096_325_input.npy (deflated 82%)
#   adding: content/npy_img/L310_90_target.npy (deflated 82%)
#   adding: content/npy_img/L143_96_target.npy (deflated 81%)
#   adding: content/npy_img/L506_147_target.npy (deflated 82%)
#   adding: content/npy_img/L506_195_target.npy (deflated 81%)
#   adding: content/npy_img/L291_2_input.npy (deflated 81%)
#   adding: content/npy_img/L286_112_input.npy (deflated 81%)
#   adding: content/npy_img/L096_119_input.npy (deflated 81%)
#   adding: content/npy_img/L286_49_input.npy (deflated 82%)
#   adding: content/npy_img/L291_268_target.npy (deflated 81%)
#   adding: content/npy_img/L291_92_target.npy (deflated 82%)
#   adding: content/npy_img/L333_44_input.npy (deflated 82%)
#   adding: content/npy_img/L310_86_target.npy (deflated 82%)
#   adding: content/npy_img/L310_60_target.npy (deflated 83%)
#   adding: content/npy_img/L506_124_target.npy (deflated 83%)
#   adding: content/npy_img/L096_90_target.npy (deflated 82%)
#   adding: content/npy_img/L310_143_input.npy (deflated 80%)
#   adding: content/npy_img/L096_249_input.npy (deflated 79%)
#   adding: content/npy_img/L096_225_target.npy (deflated 81%)
#   adding: content/npy_img/L333_63_target.npy (deflated 83%)
#   adding: content/npy_img/L143_42_target.npy (deflated 82%)
#   adding: content/npy_img/L096_232_target.npy (deflated 81%)
#   adding: content/npy_img/L333_119_target.npy (deflated 82%)
#   adding: content/npy_img/L192_133_input.npy (deflated 82%)
#   adding: content/npy_img/L333_78_input.npy (deflated 82%)
#   adding: content/npy_img/L143_200_input.npy (deflated 81%)
#   adding: content/npy_img/L506_70_input.npy (deflated 81%)
#   adding: content/npy_img/L143_162_target.npy (deflated 81%)
#   adding: content/npy_img/L286_27_target.npy (deflated 83%)
#   adding: content/npy_img/L310_176_target.npy (deflated 82%)
#   adding: content/npy_img/L291_300_input.npy (deflated 81%)
#   adding: content/npy_img/L096_247_target.npy (deflated 81%)
#   adding: content/npy_img/L333_81_input.npy (deflated 81%)
#   adding: content/npy_img/L291_301_target.npy (deflated 82%)
#   adding: content/npy_img/L286_62_input.npy (deflated 81%)
#   adding: content/npy_img/L067_86_target.npy (deflated 82%)
#   adding: content/npy_img/L096_92_input.npy (deflated 80%)
#   adding: content/npy_img/L291_106_input.npy (deflated 80%)
#   adding: content/npy_img/L096_15_target.npy (deflated 84%)
#   adding: content/npy_img/L291_216_target.npy (deflated 81%)
#   adding: content/npy_img/L109_122_input.npy (deflated 81%)
#   adding: content/npy_img/L506_94_target.npy (deflated 82%)
#   adding: content/npy_img/L506_25_target.npy (deflated 83%)
#   adding: content/npy_img/L291_196_input.npy (deflated 79%)
#   adding: content/npy_img/L067_161_input.npy (deflated 80%)
#   adding: content/npy_img/L067_36_target.npy (deflated 82%)
#   adding: content/npy_img/L291_288_target.npy (deflated 81%)
#   adding: content/npy_img/L506_27_target.npy (deflated 83%)
#   adding: content/npy_img/L506_154_input.npy (deflated 81%)
#   adding: content/npy_img/L291_146_target.npy (deflated 81%)
#   adding: content/npy_img/L067_116_target.npy (deflated 81%)
#   adding: content/npy_img/L286_13_input.npy (deflated 82%)
#   adding: content/npy_img/L286_173_input.npy (deflated 81%)
#   adding: content/npy_img/L143_20_target.npy (deflated 82%)
#   adding: content/npy_img/L192_201_input.npy (deflated 80%)
#   adding: content/npy_img/L096_202_target.npy (deflated 82%)
#   adding: content/npy_img/L192_237_input.npy (deflated 80%)
#   adding: content/npy_img/L096_120_input.npy (deflated 81%)
#   adding: content/npy_img/L096_220_input.npy (deflated 80%)
#   adding: content/npy_img/L286_132_target.npy (deflated 82%)
#   adding: content/npy_img/L506_173_input.npy (deflated 80%)
#   adding: content/npy_img/L286_63_target.npy (deflated 83%)
#   adding: content/npy_img/L096_69_input.npy (deflated 80%)
#   adding: content/npy_img/L096_151_input.npy (deflated 81%)
#   adding: content/npy_img/L067_149_input.npy (deflated 80%)
#   adding: content/npy_img/L333_34_input.npy (deflated 82%)
#   adding: content/npy_img/L286_90_target.npy (deflated 82%)
#   adding: content/npy_img/L506_209_input.npy (deflated 80%)
#   adding: content/npy_img/L291_142_input.npy (deflated 80%)
#   adding: content/npy_img/L143_133_input.npy (deflated 81%)
#   adding: content/npy_img/L286_1_input.npy (deflated 82%)
#   adding: content/npy_img/L310_164_input.npy (deflated 80%)
#   adding: content/npy_img/L310_125_target.npy (deflated 82%)
#   adding: content/npy_img/L096_256_target.npy (deflated 81%)
#   adding: content/npy_img/L109_124_input.npy (deflated 80%)
#   adding: content/npy_img/L310_190_target.npy (deflated 82%)
#   adding: content/npy_img/L286_183_target.npy (deflated 82%)
#   adding: content/npy_img/L143_202_target.npy (deflated 82%)
#   adding: content/npy_img/L333_129_input.npy (deflated 81%)
#   adding: content/npy_img/L192_114_input.npy (deflated 82%)
#   adding: content/npy_img/L143_126_input.npy (deflated 81%)
#   adding: content/npy_img/L506_54_target.npy (deflated 83%)
#   adding: content/npy_img/L096_231_input.npy (deflated 80%)
#   adding: content/npy_img/L286_108_input.npy (deflated 81%)
#   adding: content/npy_img/L067_157_input.npy (deflated 80%)
#   adding: content/npy_img/L067_220_input.npy (deflated 79%)
#   adding: content/npy_img/L333_192_input.npy (deflated 80%)
#   adding: content/npy_img/L506_205_target.npy (deflated 81%)
#   adding: content/npy_img/L506_86_target.npy (deflated 82%)
#   adding: content/npy_img/L067_116_input.npy (deflated 80%)
#   adding: content/npy_img/L067_73_target.npy (deflated 81%)
#   adding: content/npy_img/L109_40_target.npy (deflated 82%)
#   adding: content/npy_img/L192_82_target.npy (deflated 82%)
#   adding: content/npy_img/L067_219_input.npy (deflated 79%)
#   adding: content/npy_img/L096_276_input.npy (deflated 80%)
#   adding: content/npy_img/L286_79_target.npy (deflated 82%)
#   adding: content/npy_img/L096_299_target.npy (deflated 82%)
#   adding: content/npy_img/L310_24_input.npy (deflated 82%)
#   adding: content/npy_img/L192_184_target.npy (deflated 82%)
#   adding: content/npy_img/L143_5_target.npy (deflated 81%)
#   adding: content/npy_img/L143_82_target.npy (deflated 81%)
#   adding: content/npy_img/L286_46_target.npy (deflated 83%)
#   adding: content/npy_img/L096_268_input.npy (deflated 80%)
#   adding: content/npy_img/L143_173_input.npy (deflated 80%)
#   adding: content/npy_img/L109_85_input.npy (deflated 80%)
#   adding: content/npy_img/L096_307_input.npy (deflated 80%)
#   adding: content/npy_img/L286_144_target.npy (deflated 82%)
#   adding: content/npy_img/L067_44_input.npy (deflated 80%)
#   adding: content/npy_img/L506_180_target.npy (deflated 81%)
#   adding: content/npy_img/L333_236_input.npy (deflated 80%)
#   adding: content/npy_img/L096_95_target.npy (deflated 82%)
#   adding: content/npy_img/L096_25_input.npy (deflated 82%)
#   adding: content/npy_img/L192_227_target.npy (deflated 81%)
#   adding: content/npy_img/L310_200_target.npy (deflated 82%)
#   adding: content/npy_img/L286_147_target.npy (deflated 82%)
#   adding: content/npy_img/L286_45_input.npy (deflated 82%)
#   adding: content/npy_img/L143_219_input.npy (deflated 82%)
#   adding: content/npy_img/L109_24_input.npy (deflated 81%)
#   adding: content/npy_img/L109_57_target.npy (deflated 82%)
#   adding: content/npy_img/L192_148_input.npy (deflated 81%)
#   adding: content/npy_img/L109_107_input.npy (deflated 80%)
#   adding: content/npy_img/L506_99_input.npy (deflated 81%)
#   adding: content/npy_img/L096_123_target.npy (deflated 82%)
#   adding: content/npy_img/L291_67_input.npy (deflated 81%)
#   adding: content/npy_img/L143_45_input.npy (deflated 80%)
#   adding: content/npy_img/L506_114_input.npy (deflated 81%)
#   adding: content/npy_img/L310_57_input.npy (deflated 81%)
#   adding: content/npy_img/L333_40_input.npy (deflated 82%)
#   adding: content/npy_img/L310_161_target.npy (deflated 82%)
#   adding: content/npy_img/L067_79_input.npy (deflated 80%)
#   adding: content/npy_img/L109_74_input.npy (deflated 80%)
#   adding: content/npy_img/L096_293_target.npy (deflated 82%)
#   adding: content/npy_img/L192_95_input.npy (deflated 81%)
#   adding: content/npy_img/L192_57_target.npy (deflated 83%)
#   adding: content/npy_img/L291_128_target.npy (deflated 81%)
#   adding: content/npy_img/L143_152_input.npy (deflated 80%)
#   adding: content/npy_img/L310_172_input.npy (deflated 80%)
#   adding: content/npy_img/L096_50_target.npy (deflated 82%)
#   adding: content/npy_img/L192_18_target.npy (deflated 84%)
#   adding: content/npy_img/L096_272_target.npy (deflated 81%)
#   adding: content/npy_img/L310_123_input.npy (deflated 80%)
#   adding: content/npy_img/L291_122_target.npy (deflated 81%)
#   adding: content/npy_img/L506_161_target.npy (deflated 81%)
#   adding: content/npy_img/L506_76_target.npy (deflated 83%)
#   adding: content/npy_img/L291_120_input.npy (deflated 80%)
#   adding: content/npy_img/L333_102_target.npy (deflated 82%)
#   adding: content/npy_img/L109_23_target.npy (deflated 82%)
#   adding: content/npy_img/L506_102_input.npy (deflated 81%)
#   adding: content/npy_img/L506_4_input.npy (deflated 82%)
#   adding: content/npy_img/L291_234_target.npy (deflated 81%)
#   adding: content/npy_img/L192_42_target.npy (deflated 83%)
#   adding: content/npy_img/L143_94_target.npy (deflated 81%)
#   adding: content/npy_img/L109_90_target.npy (deflated 82%)
#   adding: content/npy_img/L291_170_target.npy (deflated 81%)
#   adding: content/npy_img/L291_336_target.npy (deflated 84%)
#   adding: content/npy_img/L310_200_input.npy (deflated 80%)
#   adding: content/npy_img/L286_52_input.npy (deflated 82%)
#   adding: content/npy_img/L506_103_input.npy (deflated 81%)
#   adding: content/npy_img/L310_196_target.npy (deflated 82%)
#   adding: content/npy_img/L310_22_input.npy (deflated 82%)
#   adding: content/npy_img/L109_60_input.npy (deflated 81%)
#   adding: content/npy_img/L192_30_target.npy (deflated 83%)
#   adding: content/npy_img/L291_247_input.npy (deflated 80%)
#   adding: content/npy_img/L291_1_target.npy (deflated 83%)
#   adding: content/npy_img/L067_216_input.npy (deflated 79%)
#   adding: content/npy_img/L143_65_target.npy (deflated 81%)
#   adding: content/npy_img/L067_143_input.npy (deflated 80%)
#   adding: content/npy_img/L192_158_target.npy (deflated 82%)
#   adding: content/npy_img/L286_66_target.npy (deflated 83%)
#   adding: content/npy_img/L286_100_input.npy (deflated 81%)
#   adding: content/npy_img/L143_102_target.npy (deflated 81%)
#   adding: content/npy_img/L310_50_target.npy (deflated 83%)
#   adding: content/npy_img/L096_219_input.npy (deflated 80%)
#   adding: content/npy_img/L506_6_target.npy (deflated 83%)
#   adding: content/npy_img/L192_7_target.npy (deflated 84%)
#   adding: content/npy_img/L096_210_target.npy (deflated 82%)
#   adding: content/npy_img/L143_199_input.npy (deflated 81%)
#   adding: content/npy_img/L067_206_input.npy (deflated 80%)
#   adding: content/npy_img/L096_20_target.npy (deflated 83%)
#   adding: content/npy_img/L067_28_input.npy (deflated 80%)
#   adding: content/npy_img/L291_32_input.npy (deflated 81%)
#   adding: content/npy_img/L096_58_input.npy (deflated 81%)
#   adding: content/npy_img/L286_150_input.npy (deflated 81%)
#   adding: content/npy_img/L096_63_input.npy (deflated 80%)
#   adding: content/npy_img/L291_98_input.npy (deflated 80%)
#   adding: content/npy_img/L096_326_input.npy (deflated 82%)
#   adding: content/npy_img/L192_216_input.npy (deflated 81%)
#   adding: content/npy_img/L143_140_target.npy (deflated 82%)
#   adding: content/npy_img/L310_62_target.npy (deflated 83%)
#   adding: content/npy_img/L291_196_target.npy (deflated 81%)
#   adding: content/npy_img/L143_38_target.npy (deflated 82%)
#   adding: content/npy_img/L143_164_input.npy (deflated 80%)
#   adding: content/npy_img/L192_40_target.npy (deflated 83%)
#   adding: content/npy_img/L067_214_target.npy (deflated 80%)
#   adding: content/npy_img/L286_84_target.npy (deflated 82%)
#   adding: content/npy_img/L096_195_input.npy (deflated 81%)
#   adding: content/npy_img/L333_130_input.npy (deflated 81%)
#   adding: content/npy_img/L291_62_target.npy (deflated 83%)
#   adding: content/npy_img/L096_280_input.npy (deflated 80%)
#   adding: content/npy_img/L067_5_target.npy (deflated 82%)
#   adding: content/npy_img/L143_159_target.npy (deflated 81%)
#   adding: content/npy_img/L096_318_input.npy (deflated 80%)
#   adding: content/npy_img/L310_15_input.npy (deflated 82%)
#   adding: content/npy_img/L333_159_input.npy (deflated 81%)
#   adding: content/npy_img/L291_173_input.npy (deflated 80%)
#   adding: content/npy_img/L310_21_input.npy (deflated 82%)
#   adding: content/npy_img/L096_33_target.npy (deflated 83%)
#   adding: content/npy_img/L067_100_input.npy (deflated 80%)
#   adding: content/npy_img/L096_7_input.npy (deflated 82%)
#   adding: content/npy_img/L291_45_target.npy (deflated 82%)
#   adding: content/npy_img/L192_152_target.npy (deflated 83%)
#   adding: content/npy_img/L286_167_input.npy (deflated 81%)
#   adding: content/npy_img/L506_25_input.npy (deflated 82%)
#   adding: content/npy_img/L506_34_target.npy (deflated 83%)
#   adding: content/npy_img/L096_112_input.npy (deflated 80%)
#   adding: content/npy_img/L291_315_input.npy (deflated 81%)
#   adding: content/npy_img/L286_201_input.npy (deflated 81%)
#   adding: content/npy_img/L096_76_target.npy (deflated 81%)
#   adding: content/npy_img/L286_93_input.npy (deflated 81%)
#   adding: content/npy_img/L333_114_input.npy (deflated 81%)
#   adding: content/npy_img/L506_85_target.npy (deflated 82%)
#   adding: content/npy_img/L096_313_input.npy (deflated 80%)
#   adding: content/npy_img/L192_173_input.npy (deflated 81%)
#   adding: content/npy_img/L333_67_target.npy (deflated 83%)
#   adding: content/npy_img/L291_231_target.npy (deflated 81%)
#   adding: content/npy_img/L109_7_target.npy (deflated 82%)
#   adding: content/npy_img/L096_21_target.npy (deflated 83%)
#   adding: content/npy_img/L109_1_target.npy (deflated 82%)
#   adding: content/npy_img/L067_35_input.npy (deflated 80%)
#   adding: content/npy_img/L109_29_input.npy (deflated 81%)
#   adding: content/npy_img/L143_208_input.npy (deflated 81%)
#   adding: content/npy_img/L286_34_target.npy (deflated 83%)
#   adding: content/npy_img/L192_47_target.npy (deflated 83%)
#   adding: content/npy_img/L310_178_input.npy (deflated 80%)
#   adding: content/npy_img/L333_171_input.npy (deflated 81%)
#   adding: content/npy_img/L310_95_input.npy (deflated 81%)
#   adding: content/npy_img/L096_15_input.npy (deflated 82%)
#   adding: content/npy_img/L096_278_input.npy (deflated 80%)
#   adding: content/npy_img/L286_117_input.npy (deflated 81%)
#   adding: content/npy_img/L333_177_input.npy (deflated 81%)
#   adding: content/npy_img/L192_45_input.npy (deflated 82%)
#   adding: content/npy_img/L109_33_input.npy (deflated 81%)
#   adding: content/npy_img/L291_290_input.npy (deflated 80%)
#   adding: content/npy_img/L067_70_input.npy (deflated 80%)
#   adding: content/npy_img/L096_283_input.npy (deflated 80%)
#   adding: content/npy_img/L143_157_input.npy (deflated 80%)
#   adding: content/npy_img/L096_6_input.npy (deflated 82%)
#   adding: content/npy_img/L506_162_target.npy (deflated 81%)
#   adding: content/npy_img/L310_77_target.npy (deflated 82%)
#   adding: content/npy_img/L143_41_target.npy (deflated 82%)
#   adding: content/npy_img/L096_80_input.npy (deflated 80%)
#   adding: content/npy_img/L506_97_input.npy (deflated 81%)
#   adding: content/npy_img/L333_98_input.npy (deflated 81%)
#   adding: content/npy_img/L291_187_target.npy (deflated 81%)
#   adding: content/npy_img/L096_109_target.npy (deflated 82%)
#   adding: content/npy_img/L310_77_input.npy (deflated 80%)
#   adding: content/npy_img/L333_211_target.npy (deflated 82%)
#   adding: content/npy_img/L109_27_input.npy (deflated 81%)
#   adding: content/npy_img/L143_205_input.npy (deflated 81%)
#   adding: content/npy_img/L291_92_input.npy (deflated 80%)
#   adding: content/npy_img/L333_47_target.npy (deflated 83%)
#   adding: content/npy_img/L506_9_target.npy (deflated 84%)
#   adding: content/npy_img/L291_282_input.npy (deflated 80%)
#   adding: content/npy_img/L067_26_input.npy (deflated 80%)
#   adding: content/npy_img/L096_303_target.npy (deflated 82%)
#   adding: content/npy_img/L096_322_target.npy (deflated 82%)
#   adding: content/npy_img/L286_36_input.npy (deflated 82%)
#   adding: content/npy_img/L291_123_input.npy (deflated 80%)
#   adding: content/npy_img/L291_188_target.npy (deflated 81%)
#   adding: content/npy_img/L286_136_input.npy (deflated 81%)
#   adding: content/npy_img/L192_230_input.npy (deflated 80%)
#   adding: content/npy_img/L109_59_target.npy (deflated 82%)
#   adding: content/npy_img/L291_58_target.npy (deflated 83%)
#   adding: content/npy_img/L506_172_target.npy (deflated 81%)
#   adding: content/npy_img/L310_40_input.npy (deflated 82%)
#   adding: content/npy_img/L067_91_input.npy (deflated 80%)
#   adding: content/npy_img/L310_159_target.npy (deflated 82%)
#   adding: content/npy_img/L192_88_target.npy (deflated 82%)
#   adding: content/npy_img/L506_33_input.npy (deflated 82%)
#   adding: content/npy_img/L192_59_input.npy (deflated 82%)
#   adding: content/npy_img/L067_176_input.npy (deflated 79%)
#   adding: content/npy_img/L506_48_input.npy (deflated 81%)
#   adding: content/npy_img/L143_166_target.npy (deflated 81%)
#   adding: content/npy_img/L096_327_input.npy (deflated 82%)
#   adding: content/npy_img/L286_40_input.npy (deflated 82%)
#   adding: content/npy_img/L067_112_input.npy (deflated 80%)
#   adding: content/npy_img/L286_168_target.npy (deflated 82%)
#   adding: content/npy_img/L143_182_input.npy (deflated 80%)
#   adding: content/npy_img/L143_114_target.npy (deflated 81%)
#   adding: content/npy_img/L333_137_target.npy (deflated 83%)
#   adding: content/npy_img/L109_39_input.npy (deflated 81%)
#   adding: content/npy_img/L506_123_input.npy (deflated 81%)
#   adding: content/npy_img/L109_119_input.npy (deflated 81%)
#   adding: content/npy_img/L291_66_target.npy (deflated 83%)
#   adding: content/npy_img/L291_238_input.npy (deflated 80%)
#   adding: content/npy_img/L333_12_target.npy (deflated 84%)
#   adding: content/npy_img/L143_150_input.npy (deflated 80%)
#   adding: content/npy_img/L291_339_target.npy (deflated 84%)
#   adding: content/npy_img/L310_109_input.npy (deflated 81%)
#   adding: content/npy_img/L333_146_input.npy (deflated 81%)
#   adding: content/npy_img/L096_156_input.npy (deflated 81%)
#   adding: content/npy_img/L143_1_input.npy (deflated 80%)
#   adding: content/npy_img/L067_101_target.npy (deflated 81%)
#   adding: content/npy_img/L310_5_target.npy (deflated 84%)
#   adding: content/npy_img/L067_18_target.npy (deflated 82%)
#   adding: content/npy_img/L310_157_input.npy (deflated 80%)
#   adding: content/npy_img/L067_115_input.npy (deflated 80%)
#   adding: content/npy_img/L506_91_target.npy (deflated 83%)
#   adding: content/npy_img/L310_147_target.npy (deflated 82%)
#   adding: content/npy_img/L096_302_target.npy (deflated 82%)
#   adding: content/npy_img/L096_52_input.npy (deflated 81%)
#   adding: content/npy_img/L506_12_input.npy (deflated 82%)
#   adding: content/npy_img/L096_146_target.npy (deflated 82%)
#   adding: content/npy_img/L143_61_input.npy (deflated 80%)
#   adding: content/npy_img/L286_199_target.npy (deflated 82%)
#   adding: content/npy_img/L096_13_input.npy (deflated 82%)
#   adding: content/npy_img/L096_172_target.npy (deflated 82%)
#   adding: content/npy_img/L333_119_input.npy (deflated 81%)
#   adding: content/npy_img/L096_43_target.npy (deflated 83%)
#   adding: content/npy_img/L291_17_input.npy (deflated 81%)
#   adding: content/npy_img/L109_104_target.npy (deflated 82%)
#   adding: content/npy_img/L310_11_input.npy (deflated 82%)
#   adding: content/npy_img/L143_12_target.npy (deflated 81%)
#   adding: content/npy_img/L291_116_target.npy (deflated 81%)
#   adding: content/npy_img/L291_340_input.npy (deflated 83%)
#   adding: content/npy_img/L310_141_target.npy (deflated 82%)
#   adding: content/npy_img/L143_60_target.npy (deflated 81%)
#   adding: content/npy_img/L096_122_target.npy (deflated 82%)
#   adding: content/npy_img/L096_62_input.npy (deflated 80%)
#   adding: content/npy_img/L192_4_input.npy (deflated 82%)
#   adding: content/npy_img/L291_293_target.npy (deflated 82%)
#   adding: content/npy_img/L333_18_target.npy (deflated 84%)
#   adding: content/npy_img/L109_32_input.npy (deflated 81%)
#   adding: content/npy_img/L333_141_input.npy (deflated 81%)
#   adding: content/npy_img/L286_190_target.npy (deflated 82%)
#   adding: content/npy_img/L506_179_input.npy (deflated 79%)
#   adding: content/npy_img/L067_161_target.npy (deflated 81%)
#   adding: content/npy_img/L291_250_input.npy (deflated 80%)
#   adding: content/npy_img/L333_55_target.npy (deflated 83%)
#   adding: content/npy_img/L310_164_target.npy (deflated 82%)
#   adding: content/npy_img/L143_222_input.npy (deflated 82%)
#   adding: content/npy_img/L096_154_input.npy (deflated 81%)
#   adding: content/npy_img/L506_80_input.npy (deflated 81%)
#   adding: content/npy_img/L506_111_target.npy (deflated 82%)
#   adding: content/npy_img/L291_124_input.npy (deflated 80%)
#   adding: content/npy_img/L192_218_target.npy (deflated 82%)
#   adding: content/npy_img/L192_109_target.npy (deflated 83%)
#   adding: content/npy_img/L192_132_target.npy (deflated 83%)
#   adding: content/npy_img/L067_112_target.npy (deflated 81%)
#   adding: content/npy_img/L096_169_target.npy (deflated 82%)
#   adding: content/npy_img/L506_115_input.npy (deflated 81%)
#   adding: content/npy_img/L286_196_input.npy (deflated 81%)
#   adding: content/npy_img/L192_232_target.npy (deflated 81%)
#   adding: content/npy_img/L067_160_target.npy (deflated 81%)
#   adding: content/npy_img/L192_145_target.npy (deflated 83%)
#   adding: content/npy_img/L291_127_input.npy (deflated 80%)
#   adding: content/npy_img/L067_30_target.npy (deflated 82%)
#   adding: content/npy_img/L096_231_target.npy (deflated 81%)
#   adding: content/npy_img/L506_76_input.npy (deflated 81%)
#   adding: content/npy_img/L310_61_target.npy (deflated 83%)
#   adding: content/npy_img/L506_203_target.npy (deflated 81%)
#   adding: content/npy_img/L143_209_input.npy (deflated 81%)
#   adding: content/npy_img/L291_268_input.npy (deflated 80%)
#   adding: content/npy_img/L143_78_input.npy (deflated 80%)
#   adding: content/npy_img/L286_17_input.npy (deflated 82%)
#   adding: content/npy_img/L096_26_target.npy (deflated 83%)
#   adding: content/npy_img/L310_73_input.npy (deflated 80%)
#   adding: content/npy_img/L506_51_input.npy (deflated 81%)
#   adding: content/npy_img/L109_39_target.npy (deflated 82%)
#   adding: content/npy_img/L192_75_target.npy (deflated 83%)
#   adding: content/npy_img/L109_67_input.npy (deflated 80%)
#   adding: content/npy_img/L192_206_input.npy (deflated 80%)
#   adding: content/npy_img/L333_3_input.npy (deflated 82%)
#   adding: content/npy_img/L291_160_input.npy (deflated 80%)
#   adding: content/npy_img/L310_180_target.npy (deflated 81%)
#   adding: content/npy_img/L310_132_target.npy (deflated 82%)
#   adding: content/npy_img/L143_8_input.npy (deflated 80%)
#   adding: content/npy_img/L506_166_target.npy (deflated 81%)
#   adding: content/npy_img/L333_126_target.npy (deflated 82%)
#   adding: content/npy_img/L286_140_target.npy (deflated 82%)
#   adding: content/npy_img/L310_106_input.npy (deflated 81%)
#   adding: content/npy_img/L096_285_target.npy (deflated 81%)
#   adding: content/npy_img/L310_162_target.npy (deflated 82%)
#   adding: content/npy_img/L096_202_input.npy (deflated 80%)
#   adding: content/npy_img/L067_146_input.npy (deflated 80%)
#   adding: content/npy_img/L192_54_input.npy (deflated 82%)
#   adding: content/npy_img/L506_118_target.npy (deflated 83%)
#   adding: content/npy_img/L067_36_input.npy (deflated 80%)
#   adding: content/npy_img/L096_47_input.npy (deflated 81%)
#   adding: content/npy_img/L506_121_input.npy (deflated 81%)
#   adding: content/npy_img/L192_75_input.npy (deflated 81%)
#   adding: content/npy_img/L333_223_target.npy (deflated 82%)
#   adding: content/npy_img/L506_200_input.npy (deflated 80%)
#   adding: content/npy_img/L310_41_target.npy (deflated 83%)
#   adding: content/npy_img/L291_183_input.npy (deflated 79%)
#   adding: content/npy_img/L333_211_input.npy (deflated 81%)
#   adding: content/npy_img/L291_260_target.npy (deflated 81%)
#   adding: content/npy_img/L291_138_input.npy (deflated 80%)
#   adding: content/npy_img/L067_208_target.npy (deflated 81%)
#   adding: content/npy_img/L192_1_input.npy (deflated 82%)
#   adding: content/npy_img/L192_140_input.npy (deflated 82%)
#   adding: content/npy_img/L333_226_input.npy (deflated 81%)
#   adding: content/npy_img/L143_193_target.npy (deflated 82%)
#   adding: content/npy_img/L143_99_input.npy (deflated 80%)
#   adding: content/npy_img/L291_222_target.npy (deflated 81%)
#   adding: content/npy_img/L291_64_target.npy (deflated 83%)
#   adding: content/npy_img/L096_266_input.npy (deflated 80%)
#   adding: content/npy_img/L333_17_input.npy (deflated 82%)
#   adding: content/npy_img/L286_178_input.npy (deflated 81%)
#   adding: content/npy_img/L192_52_target.npy (deflated 83%)
#   adding: content/npy_img/L310_126_input.npy (deflated 80%)
#   adding: content/npy_img/L286_95_input.npy (deflated 81%)
#   adding: content/npy_img/L310_129_input.npy (deflated 80%)
#   adding: content/npy_img/L067_10_target.npy (deflated 82%)
#   adding: content/npy_img/L192_46_input.npy (deflated 82%)
#   adding: content/npy_img/L310_64_target.npy (deflated 82%)
#   adding: content/npy_img/L291_6_target.npy (deflated 83%)
#   adding: content/npy_img/L506_37_input.npy (deflated 82%)
#   adding: content/npy_img/L333_233_input.npy (deflated 81%)
#   adding: content/npy_img/L310_13_input.npy (deflated 82%)
#   adding: content/npy_img/L192_117_input.npy (deflated 82%)
#   adding: content/npy_img/L192_138_input.npy (deflated 82%)
#   adding: content/npy_img/L109_102_target.npy (deflated 81%)
#   adding: content/npy_img/L096_87_input.npy (deflated 80%)
#   adding: content/npy_img/L067_11_target.npy (deflated 82%)
#   adding: content/npy_img/L333_52_input.npy (deflated 82%)
#   adding: content/npy_img/L291_224_input.npy (deflated 80%)
#   adding: content/npy_img/L333_87_input.npy (deflated 81%)
#   adding: content/npy_img/L291_273_target.npy (deflated 81%)
#   adding: content/npy_img/L192_128_target.npy (deflated 83%)
#   adding: content/npy_img/L192_134_input.npy (deflated 82%)
#   adding: content/npy_img/L109_53_input.npy (deflated 81%)
#   adding: content/npy_img/L286_20_input.npy (deflated 82%)
#   adding: content/npy_img/L333_94_input.npy (deflated 81%)
#   adding: content/npy_img/L291_211_target.npy (deflated 81%)
#   adding: content/npy_img/L143_121_target.npy (deflated 82%)
#   adding: content/npy_img/L291_339_input.npy (deflated 83%)
#   adding: content/npy_img/L067_168_input.npy (deflated 80%)
#   adding: content/npy_img/L291_310_target.npy (deflated 82%)
#   adding: content/npy_img/L291_326_input.npy (deflated 82%)
#   adding: content/npy_img/L143_163_input.npy (deflated 80%)
#   adding: content/npy_img/L310_190_input.npy (deflated 80%)
#   adding: content/npy_img/L143_69_target.npy (deflated 81%)
#   adding: content/npy_img/L506_80_target.npy (deflated 83%)
#   adding: content/npy_img/L333_33_input.npy (deflated 82%)
#   adding: content/npy_img/L333_217_input.npy (deflated 81%)
#   adding: content/npy_img/L291_184_target.npy (deflated 81%)
#   adding: content/npy_img/L310_173_input.npy (deflated 80%)
#   adding: content/npy_img/L291_313_target.npy (deflated 82%)
#   adding: content/npy_img/L291_114_input.npy (deflated 80%)
#   adding: content/npy_img/L096_155_input.npy (deflated 81%)
#   adding: content/npy_img/L506_68_input.npy (deflated 81%)
#   adding: content/npy_img/L143_175_target.npy (deflated 81%)
#   adding: content/npy_img/L067_55_target.npy (deflated 82%)
#   adding: content/npy_img/L192_162_input.npy (deflated 81%)
#   adding: content/npy_img/L333_173_input.npy (deflated 81%)
#   adding: content/npy_img/L109_99_target.npy (deflated 81%)
#   adding: content/npy_img/L310_10_input.npy (deflated 82%)
#   adding: content/npy_img/L333_217_target.npy (deflated 82%)
#   adding: content/npy_img/L067_12_input.npy (deflated 80%)
#   adding: content/npy_img/L506_40_target.npy (deflated 83%)
#   adding: content/npy_img/L096_81_input.npy (deflated 80%)
#   adding: content/npy_img/L143_174_target.npy (deflated 81%)
#   adding: content/npy_img/L067_213_input.npy (deflated 79%)
#   adding: content/npy_img/L109_70_input.npy (deflated 80%)
#   adding: content/npy_img/L192_142_target.npy (deflated 83%)
#   adding: content/npy_img/L291_191_input.npy (deflated 79%)
#   adding: content/npy_img/L291_338_target.npy (deflated 84%)
#   adding: content/npy_img/L143_81_target.npy (deflated 81%)
#   adding: content/npy_img/L333_88_input.npy (deflated 81%)
#   adding: content/npy_img/L333_56_input.npy (deflated 82%)
#   adding: content/npy_img/L192_72_input.npy (deflated 81%)
#   adding: content/npy_img/L291_295_input.npy (deflated 81%)
#   adding: content/npy_img/L143_8_target.npy (deflated 81%)
#   adding: content/npy_img/L143_67_input.npy (deflated 80%)
#   adding: content/npy_img/L096_214_input.npy (deflated 80%)
#   adding: content/npy_img/L096_0_target.npy (deflated 83%)
#   adding: content/npy_img/L096_301_input.npy (deflated 81%)
#   adding: content/npy_img/L096_306_input.npy (deflated 81%)
#   adding: content/npy_img/L192_165_input.npy (deflated 81%)
#   adding: content/npy_img/L192_3_target.npy (deflated 84%)
#   adding: content/npy_img/L286_88_input.npy (deflated 81%)
#   adding: content/npy_img/L310_116_target.npy (deflated 82%)
#   adding: content/npy_img/L333_166_target.npy (deflated 82%)
#   adding: content/npy_img/L286_145_target.npy (deflated 82%)
#   adding: content/npy_img/L067_121_input.npy (deflated 80%)
#   adding: content/npy_img/L192_32_target.npy (deflated 83%)
#   adding: content/npy_img/L333_27_target.npy (deflated 83%)
#   adding: content/npy_img/L067_91_target.npy (deflated 81%)
#   adding: content/npy_img/L143_180_input.npy (deflated 80%)
#   adding: content/npy_img/L333_137_input.npy (deflated 81%)
#   adding: content/npy_img/L192_110_input.npy (deflated 82%)
#   adding: content/npy_img/L067_159_target.npy (deflated 81%)
#   adding: content/npy_img/L286_50_target.npy (deflated 83%)
#   adding: content/npy_img/L506_18_input.npy (deflated 82%)
#   adding: content/npy_img/L109_67_target.npy (deflated 82%)
#   adding: content/npy_img/L291_144_input.npy (deflated 80%)
#   adding: content/npy_img/L506_116_input.npy (deflated 81%)
#   adding: content/npy_img/L067_49_input.npy (deflated 80%)
#   adding: content/npy_img/L096_77_input.npy (deflated 80%)
#   adding: content/npy_img/L067_120_target.npy (deflated 82%)
#   adding: content/npy_img/L291_226_input.npy (deflated 80%)
#   adding: content/npy_img/L096_165_target.npy (deflated 82%)
#   adding: content/npy_img/L192_111_target.npy (deflated 83%)
#   adding: content/npy_img/L310_194_input.npy (deflated 80%)
#   adding: content/npy_img/L192_197_input.npy (deflated 80%)
#   adding: content/npy_img/L067_173_target.npy (deflated 81%)
#   adding: content/npy_img/L192_81_target.npy (deflated 83%)
#   adding: content/npy_img/L310_104_target.npy (deflated 83%)
#   adding: content/npy_img/L096_274_input.npy (deflated 80%)
#   adding: content/npy_img/L096_312_target.npy (deflated 82%)
#   adding: content/npy_img/L143_198_input.npy (deflated 81%)
#   adding: content/npy_img/L291_257_input.npy (deflated 79%)
#   adding: content/npy_img/L333_45_target.npy (deflated 83%)
#   adding: content/npy_img/L067_182_target.npy (deflated 81%)
#   adding: content/npy_img/L096_260_input.npy (deflated 79%)
#   adding: content/npy_img/L096_186_target.npy (deflated 82%)
#   adding: content/npy_img/L291_161_input.npy (deflated 80%)
#   adding: content/npy_img/L333_24_target.npy (deflated 83%)
#   adding: content/npy_img/L067_193_target.npy (deflated 81%)
#   adding: content/npy_img/L143_182_target.npy (deflated 81%)
#   adding: content/npy_img/L286_21_target.npy (deflated 83%)
#   adding: content/npy_img/L143_6_target.npy (deflated 81%)
#   adding: content/npy_img/L067_139_input.npy (deflated 80%)
#   adding: content/npy_img/L143_108_target.npy (deflated 81%)
#   adding: content/npy_img/L506_11_target.npy (deflated 84%)
# ...
#   adding: content/npy_img/L291_258_input.npy (deflated 79%)
#   adding: content/npy_img/L143_27_input.npy (deflated 80%)
#   adding: content/npy_img/L333_114_target.npy (deflated 82%)
#   adding: content/npy_img/L310_61_input.npy (deflated 81%)
#   adding: content/npy_img/L096_3_input.npy (deflated 82%)
#   adding: content/npy_img/L333_182_target.npy (deflated 82%)
#   adding: content/npy_img/L096_79_target.npy (deflated 81%)
#   adding: content/npy_img/L310_75_target.npy (deflated 82%)
#   adding: content/npy_img/L333_143_input.npy (deflated 81%)
#   adding: content/npy_img/L310_210_target.npy (deflated 81%)
#   adding: content/npy_img/L067_148_target.npy (deflated 81%)
#   adding: content/npy_img/L143_184_input.npy (deflated 80%)
#   adding: content/npy_img/L192_176_target.npy (deflated 82%)
#   adding: content/npy_img/L143_98_input.npy (deflated 80%)
#   adding: content/npy_img/L286_164_target.npy (deflated 82%)
#   adding: content/npy_img/L096_147_target.npy (deflated 82%)
#   adding: content/npy_img/L067_143_target.npy (deflated 81%)
#   adding: content/npy_img/L192_23_input.npy (deflated 82%)
#   adding: content/npy_img/L192_181_input.npy (deflated 80%)
#   adding: content/npy_img/L096_318_target.npy (deflated 82%)
#   adding: content/npy_img/L192_236_target.npy (deflated 81%)
#   adding: content/npy_img/L143_63_input.npy (deflated 80%)
#   adding: content/npy_img/L291_132_input.npy (deflated 80%)
#   adding: content/npy_img/L096_305_input.npy (deflated 81%)
#   adding: content/npy_img/L143_223_input.npy (deflated 82%)
#   adding: content/npy_img/L192_173_target.npy (deflated 82%)
#   adding: content/npy_img/L096_62_target.npy (deflated 82%)
#   adding: content/npy_img/L310_181_target.npy (deflated 82%)
#   adding: content/npy_img/L067_149_target.npy (deflated 81%)
#   adding: content/npy_img/L333_121_target.npy (deflated 82%)
#   adding: content/npy_img/L291_316_input.npy (deflated 81%)
#   adding: content/npy_img/L096_93_target.npy (deflated 82%)
#   adding: content/npy_img/L143_121_input.npy (deflated 81%)
#   adding: content/npy_img/L192_161_target.npy (deflated 82%)
#   adding: content/npy_img/L333_214_target.npy (deflated 82%)
#   adding: content/npy_img/L310_93_target.npy (deflated 82%)
#   adding: content/npy_img/L291_281_target.npy (deflated 81%)
#   adding: content/npy_img/L067_48_input.npy (deflated 80%)
#   adding: content/npy_img/L096_284_target.npy (deflated 81%)
#   adding: content/npy_img/L291_54_input.npy (deflated 82%)
#   adding: content/npy_img/L096_289_target.npy (deflated 81%)
#   adding: content/npy_img/L310_126_target.npy (deflated 82%)
#   adding: content/npy_img/L192_66_target.npy (deflated 83%)
#   adding: content/npy_img/L192_35_input.npy (deflated 82%)
#   adding: content/npy_img/L291_5_target.npy (deflated 83%)
#   adding: content/npy_img/L096_245_target.npy (deflated 81%)
#   adding: content/npy_img/L291_27_input.npy (deflated 81%)
#   adding: content/npy_img/L109_8_target.npy (deflated 82%)
#   adding: content/npy_img/L333_216_input.npy (deflated 81%)
#   adding: content/npy_img/L109_83_input.npy (deflated 80%)
#   adding: content/npy_img/L333_39_input.npy (deflated 82%)
#   adding: content/npy_img/L143_117_target.npy (deflated 81%)
#   adding: content/npy_img/L506_114_target.npy (deflated 82%)
#   adding: content/npy_img/L310_12_input.npy (deflated 82%)
#   adding: content/npy_img/L067_136_target.npy (deflated 81%)
#   adding: content/npy_img/L333_174_input.npy (deflated 81%)
#   adding: content/npy_img/L310_69_input.npy (deflated 80%)
#   adding: content/npy_img/L291_258_target.npy (deflated 81%)
#   adding: content/npy_img/L291_243_input.npy (deflated 80%)
#   adding: content/npy_img/L333_80_target.npy (deflated 83%)
#   adding: content/npy_img/L143_224_input.npy (deflated 82%)
#   adding: content/npy_img/L109_95_input.npy (deflated 80%)
#   adding: content/npy_img/L096_121_input.npy (deflated 81%)
#   adding: content/npy_img/L333_7_input.npy (deflated 82%)
#   adding: content/npy_img/L096_172_input.npy (deflated 81%)
#   adding: content/npy_img/L143_6_input.npy (deflated 80%)
#   adding: content/npy_img/L096_49_input.npy (deflated 81%)
#   adding: content/npy_img/L067_113_input.npy (deflated 80%)
#   adding: content/npy_img/L067_141_target.npy (deflated 81%)
#   adding: content/npy_img/L506_64_target.npy (deflated 83%)
#   adding: content/npy_img/L333_204_target.npy (deflated 82%)
#   adding: content/npy_img/L291_63_input.npy (deflated 81%)
#   adding: content/npy_img/L286_69_input.npy (deflated 81%)
#   adding: content/npy_img/L143_159_input.npy (deflated 80%)
#   adding: content/npy_img/L067_160_input.npy (deflated 80%)
#   adding: content/npy_img/L506_115_target.npy (deflated 83%)
#   adding: content/npy_img/L310_25_target.npy (deflated 84%)
#   adding: content/npy_img/L192_217_input.npy (deflated 80%)
#   adding: content/npy_img/L291_171_target.npy (deflated 81%)
#   adding: content/npy_img/L286_39_input.npy (deflated 82%)
#   adding: content/npy_img/L143_181_target.npy (deflated 81%)
#   adding: content/npy_img/L310_103_target.npy (deflated 83%)
#   adding: content/npy_img/L291_40_target.npy (deflated 83%)
#   adding: content/npy_img/L310_167_input.npy (deflated 80%)
#   adding: content/npy_img/L067_218_input.npy (deflated 79%)
#   adding: content/npy_img/L310_52_input.npy (deflated 81%)
#   adding: content/npy_img/L310_213_target.npy (deflated 81%)
#   adding: content/npy_img/L096_291_target.npy (deflated 82%)
#   adding: content/npy_img/L333_230_input.npy (deflated 81%)
#   adding: content/npy_img/L143_227_input.npy (deflated 82%)
#   adding: content/npy_img/L291_244_input.npy (deflated 80%)
#   adding: content/npy_img/L286_131_input.npy (deflated 81%)
#   adding: content/npy_img/L333_206_target.npy (deflated 82%)
#   adding: content/npy_img/L310_206_input.npy (deflated 80%)
#   adding: content/npy_img/L096_142_target.npy (deflated 82%)
#   adding: content/npy_img/L310_158_target.npy (deflated 82%)
#   adding: content/npy_img/L067_97_target.npy (deflated 81%)
#   adding: content/npy_img/L067_217_target.npy (deflated 80%)
#   adding: content/npy_img/L192_183_input.npy (deflated 81%)
#   adding: content/npy_img/L291_303_target.npy (deflated 82%)
#   adding: content/npy_img/L291_230_target.npy (deflated 81%)
#   adding: content/npy_img/L096_61_target.npy (deflated 82%)
#   adding: content/npy_img/L067_73_input.npy (deflated 80%)
#   adding: content/npy_img/L310_33_target.npy (deflated 83%)
#   adding: content/npy_img/L096_193_target.npy (deflated 82%)
#   adding: content/npy_img/L333_109_input.npy (deflated 81%)
#   adding: content/npy_img/L291_305_target.npy (deflated 82%)
#   adding: content/npy_img/L096_53_target.npy (deflated 82%)
#   adding: content/npy_img/L109_68_target.npy (deflated 82%)
#   adding: content/npy_img/L310_139_target.npy (deflated 82%)
#   adding: content/npy_img/L192_133_target.npy (deflated 83%)
#   adding: content/npy_img/L067_165_target.npy (deflated 81%)
#   adding: content/npy_img/L109_56_input.npy (deflated 81%)
#   adding: content/npy_img/L096_91_target.npy (deflated 81%)
#   adding: content/npy_img/L286_18_input.npy (deflated 82%)
#   adding: content/npy_img/L109_90_input.npy (deflated 80%)
#   adding: content/npy_img/L067_202_input.npy (deflated 79%)
#   adding: content/npy_img/L067_184_input.npy (deflated 79%)
#   adding: content/npy_img/L291_52_input.npy (deflated 82%)
#   adding: content/npy_img/L506_90_input.npy (deflated 81%)
#   adding: content/npy_img/L067_130_target.npy (deflated 82%)
#   adding: content/npy_img/L192_3_input.npy (deflated 82%)
#   adding: content/npy_img/L506_31_target.npy (deflated 83%)
#   adding: content/npy_img/L506_40_input.npy (deflated 82%)
#   adding: content/npy_img/L291_161_target.npy (deflated 81%)
#   adding: content/npy_img/L333_35_input.npy (deflated 82%)
#   adding: content/npy_img/L096_176_target.npy (deflated 82%)
#   adding: content/npy_img/L291_259_input.npy (deflated 79%)
#   adding: content/npy_img/L333_1_target.npy (deflated 84%)
#   adding: content/npy_img/L310_114_target.npy (deflated 82%)
#   adding: content/npy_img/L192_97_input.npy (deflated 81%)
#   adding: content/npy_img/L192_125_target.npy (deflated 83%)
#   adding: content/npy_img/L192_220_target.npy (deflated 81%)
#   adding: content/npy_img/L506_148_target.npy (deflated 82%)
#   adding: content/npy_img/L291_256_input.npy (deflated 79%)
#   adding: content/npy_img/L192_24_target.npy (deflated 83%)
#   adding: content/npy_img/L192_228_target.npy (deflated 81%)
#   adding: content/npy_img/L506_207_target.npy (deflated 81%)
#   adding: content/npy_img/L109_115_target.npy (deflated 82%)
#   adding: content/npy_img/L067_108_target.npy (deflated 81%)
#   adding: content/npy_img/L291_66_input.npy (deflated 81%)
#   adding: content/npy_img/L291_190_target.npy (deflated 81%)
#   adding: content/npy_img/L333_60_input.npy (deflated 82%)
#   adding: content/npy_img/L333_83_input.npy (deflated 81%)
#   adding: content/npy_img/L192_46_target.npy (deflated 83%)
#   adding: content/npy_img/L143_77_target.npy (deflated 81%)
#   adding: content/npy_img/L291_311_input.npy (deflated 81%)
#   adding: content/npy_img/L192_154_target.npy (deflated 82%)
#   adding: content/npy_img/L067_123_input.npy (deflated 80%)
#   adding: content/npy_img/L096_216_input.npy (deflated 80%)
#   adding: content/npy_img/L143_39_input.npy (deflated 80%)
#   adding: content/npy_img/L096_197_target.npy (deflated 82%)
#   adding: content/npy_img/L096_258_input.npy (deflated 79%)
#   adding: content/npy_img/L192_42_input.npy (deflated 82%)
#   adding: content/npy_img/L143_12_input.npy (deflated 80%)
#   adding: content/npy_img/L291_172_input.npy (deflated 80%)
#   adding: content/npy_img/L291_285_target.npy (deflated 81%)
#   adding: content/npy_img/L143_88_input.npy (deflated 80%)
#   adding: content/npy_img/L291_139_target.npy (deflated 81%)
#   adding: content/npy_img/L333_201_target.npy (deflated 82%)
#   adding: content/npy_img/L291_274_target.npy (deflated 81%)
#   adding: content/npy_img/L310_178_target.npy (deflated 82%)
#   adding: content/npy_img/L096_9_target.npy (deflated 84%)
#   adding: content/npy_img/L310_6_target.npy (deflated 84%)
#   adding: content/npy_img/L291_290_target.npy (deflated 81%)
#   adding: content/npy_img/L310_177_target.npy (deflated 81%)
#   adding: content/npy_img/L143_226_target.npy (deflated 83%)
#   adding: content/npy_img/L286_67_target.npy (deflated 83%)
#   adding: content/npy_img/L096_130_target.npy (deflated 82%)
#   adding: content/npy_img/L291_149_target.npy (deflated 81%)
#   adding: content/npy_img/L291_307_input.npy (deflated 81%)
#   adding: content/npy_img/L109_98_input.npy (deflated 80%)
#   adding: content/npy_img/L109_77_target.npy (deflated 82%)
#   adding: content/npy_img/L310_192_target.npy (deflated 82%)
#   adding: content/npy_img/L096_243_target.npy (deflated 81%)
#   adding: content/npy_img/L310_188_input.npy (deflated 80%)
#   adding: content/npy_img/L109_6_target.npy (deflated 82%)
#   adding: content/npy_img/L286_45_target.npy (deflated 83%)
#   adding: content/npy_img/L333_79_target.npy (deflated 83%)
#   adding: content/npy_img/L310_153_input.npy (deflated 80%)
#   adding: content/npy_img/L333_138_target.npy (deflated 82%)
#   adding: content/npy_img/L506_138_target.npy (deflated 82%)
#   adding: content/npy_img/L143_100_target.npy (deflated 81%)
#   adding: content/npy_img/L506_123_target.npy (deflated 83%)
#   adding: content/npy_img/L291_199_target.npy (deflated 81%)
#   adding: content/npy_img/L192_41_input.npy (deflated 82%)
#   adding: content/npy_img/L291_101_target.npy (deflated 81%)
#   adding: content/npy_img/L286_86_target.npy (deflated 82%)
#   adding: content/npy_img/L067_57_target.npy (deflated 82%)
#   adding: content/npy_img/L333_146_target.npy (deflated 82%)
#   adding: content/npy_img/L286_53_input.npy (deflated 82%)
#   adding: content/npy_img/L143_134_target.npy (deflated 82%)
#   adding: content/npy_img/L109_126_input.npy (deflated 80%)
#   adding: content/npy_img/L310_74_input.npy (deflated 80%)
#   adding: content/npy_img/L143_102_input.npy (deflated 80%)
#   adding: content/npy_img/L310_17_input.npy (deflated 82%)
#   adding: content/npy_img/L333_181_input.npy (deflated 81%)
#   adding: content/npy_img/L333_97_target.npy (deflated 83%)
#   adding: content/npy_img/L286_14_target.npy (deflated 83%)
#   adding: content/npy_img/L096_309_target.npy (deflated 82%)
#   adding: content/npy_img/L291_50_input.npy (deflated 81%)
#   adding: content/npy_img/L286_151_input.npy (deflated 81%)
#   adding: content/npy_img/L096_308_input.npy (deflated 80%)
#   adding: content/npy_img/L286_156_input.npy (deflated 81%)
#   adding: content/npy_img/L143_57_input.npy (deflated 80%)
#   adding: content/npy_img/L143_140_input.npy (deflated 81%)
#   adding: content/npy_img/L291_291_input.npy (deflated 80%)
#   adding: content/npy_img/L506_109_input.npy (deflated 81%)
#   adding: content/npy_img/L067_41_input.npy (deflated 80%)
#   adding: content/npy_img/L506_120_input.npy (deflated 81%)
#   adding: content/npy_img/L333_184_input.npy (deflated 80%)
#   adding: content/npy_img/L333_241_target.npy (deflated 82%)
#   adding: content/npy_img/L291_21_target.npy (deflated 83%)
#   adding: content/npy_img/L333_93_target.npy (deflated 83%)
#   adding: content/npy_img/L143_179_input.npy (deflated 80%)
#   adding: content/npy_img/L067_109_target.npy (deflated 81%)
#   adding: content/npy_img/L286_125_target.npy (deflated 82%)
#   adding: content/npy_img/L506_12_target.npy (deflated 84%)
#   adding: content/npy_img/L096_183_target.npy (deflated 82%)
#   adding: content/npy_img/L192_180_target.npy (deflated 82%)
#   adding: content/npy_img/L192_137_input.npy (deflated 82%)
#   adding: content/npy_img/L310_118_input.npy (deflated 81%)
#   adding: content/npy_img/L333_179_target.npy (deflated 82%)
#   adding: content/npy_img/L109_121_target.npy (deflated 82%)
#   adding: content/npy_img/L192_170_target.npy (deflated 82%)
#   adding: content/npy_img/L096_222_target.npy (deflated 81%)
#   adding: content/npy_img/L096_319_target.npy (deflated 82%)
#   adding: content/npy_img/L096_185_target.npy (deflated 82%)
#   adding: content/npy_img/L109_72_target.npy (deflated 82%)
#   adding: content/npy_img/L096_159_target.npy (deflated 82%)
#   adding: content/npy_img/L192_201_target.npy (deflated 82%)
#   adding: content/npy_img/L192_79_input.npy (deflated 81%)
#   adding: content/npy_img/L143_15_input.npy (deflated 80%)
#   adding: content/npy_img/L286_206_target.npy (deflated 82%)
#   adding: content/npy_img/L286_44_input.npy (deflated 82%)
#   adding: content/npy_img/L291_179_target.npy (deflated 81%)
#   adding: content/npy_img/L291_182_input.npy (deflated 79%)
#   adding: content/npy_img/L310_150_input.npy (deflated 80%)
#   adding: content/npy_img/L310_159_input.npy (deflated 80%)
#   adding: content/save/ (stored 0%)
#   adding: content/save/fig/ (stored 0%)
#   adding: content/save/loss_6000_iter.npy (deflated 51%)
#   adding: content/save/REDCNN_3000iter.ckpt (deflated 8%)
#   adding: content/save/REDCNN_13000iter.ckpt (deflated 8%)
#   adding: content/save/loss_2000_iter.npy (deflated 52%)
#   adding: content/save/loss_5000_iter.npy (deflated 51%)
#   adding: content/save/loss_9000_iter.npy (deflated 52%)
#   adding: content/save/REDCNN_11000iter.ckpt (deflated 8%)
#   adding: content/save/loss_8000_iter.npy (deflated 52%)
#   adding: content/save/REDCNN_2000iter.ckpt (deflated 8%)
#   adding: content/save/REDCNN_10000iter.ckpt (deflated 8%)
#   adding: content/save/loss_10000_iter.npy (deflated 52%)
#   adding: content/save/REDCNN_9000iter.ckpt (deflated 8%)
#   adding: content/save/REDCNN_4000iter.ckpt (deflated 8%)
#   adding: content/save/REDCNN_5000iter.ckpt (deflated 8%)
#   adding: content/save/loss_11000_iter.npy (deflated 52%)
#   adding: content/save/REDCNN_1000iter.ckpt (deflated 8%)
#   adding: content/save/loss_1000_iter.npy (deflated 51%)
#   adding: content/save/loss_4000_iter.npy (deflated 52%)
#   adding: content/save/loss_3000_iter.npy (deflated 52%)
#   adding: content/save/loss_13000_iter.npy (deflated 52%)
#   adding: content/save/REDCNN_12000iter.ckpt (deflated 8%)
#   adding: content/save/loss_12000_iter.npy (deflated 52%)
#   adding: content/save/REDCNN_7000iter.ckpt (deflated 8%)
#   adding: content/save/loss_7000_iter.npy (deflated 52%)
#   adding: content/save/REDCNN_8000iter.ckpt (deflated 8%)
#   adding: content/save/REDCNN_6000iter.ckpt (deflated 8%)
